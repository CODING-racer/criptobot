# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import yfinance as yf

# %%
ticker = "BTC-USD"
BTC_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tickers = "ETH-USD", "XRP-USD"
ETH_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
XRP_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
ETH_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
ETH_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
ETH_rd = ETH_h.rename(columns={'Open':'(ETH)Open','High':'(ETH)High','Low':'(ETH)Low','Close':'(ETH)Close','Adj Close':'(ETH)Adj Close','Volume':'(ETH)Volume'})

# %%
ETH_rd.head()
# Out:
#                (ETH)Open     (ETH)High      (ETH)Low    (ETH)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (ETH)Adj Close  (ETH)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
tickers = "LTC-USD","BCH-USD","ADA-USD","DOT-USD","BNB-USD","DOGE-USD","XLM-USD","SOL-USD","USDT-USD","UNI-USD","LINK-USD","AVAX-USD"
LTC_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
BCH_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
ADA_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
DOT_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
BNB_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
DOGE_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
XLM_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
SOL_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
USDT_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
UNI_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
LINK_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
AVAX_h = yf.download(ticker, start="2024-06-17", end="2024-08-06")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
LTC_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
LTC_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
LTC_rd = LTC_h.rename(columns={'Open':'(ETH)Open','High':'(LTC)High','Low':'(LTC)Low','Close':'(LTC)Close','Adj Close':'(LTC)Adj Close','Volume':'(LTC)Volume'})

# %%
LTC_rd.head()
# Out:
#                (ETH)Open     (LTC)High      (LTC)Low    (LTC)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (LTC)Adj Close  (LTC)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
BCH_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
BCH_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
BCH_rd = BCH_h.rename(columns={'Open':'(BCH)Open','High':'(BCH)High','Low':'(BCH)Low','Close':'(BCH)Close','Adj Close':'(BCH)Adj Close','Volume':'(BCH)Volume'})

# %%
BCH_rd.head()
# Out:
#                (BCH)Open     (BCH)High      (BCH)Low    (BCH)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (BCH)Adj Close  (BCH)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
ADA_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
ADA_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
ADA_rd = ADA_h.rename(columns={'Open':'(ADA)Open','High':'(ADA)High','Low':'(ADA)Low','Close':'(ADA)Close','Adj Close':'(ADA)Adj Close','Volume':'(ADA)Volume'})

# %%
ADA_rd.head()
# Out:
#                (ADA)Open     (ADA)High      (ADA)Low    (ADA)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (ADA)Adj Close  (ADA)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
DOT_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
DOT_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
DOT_rd = DOT_h.rename(columns={'Open':'(DOT)Open','High':'(DOT)High','Low':'(DOT)Low','Close':'(DOT)Close','Adj Close':'(DOT)Adj Close','Volume':'(DOT)Volume'})

# %%
DOT_rd.head()
# Out:
#                (DOT)Open     (DOT)High      (DOT)Low    (DOT)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (DOT)Adj Close  (DOT)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
BNB_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
BNB_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
BNB_rd = BNB_h.rename(columns={'Open':'(BNB)Open','High':'(BNB)High','Low':'(BNB)Low','Close':'(BNB)Close','Adj Close':'(BNB)Adj Close','Volume':'(BNB)Volume'})

# %%
BNB_rd.head()
# Out:
#                (BNB)Open     (BNB)High      (BNB)Low    (BNB)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (BNB)Adj Close  (BNB)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
DOGE_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
DOGE_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
DOGE_rd = DOGE_h.rename(columns={'Open':'(DOGE)Open','High':'(DOGE)High','Low':'(DOGE)Low','Close':'(DOGE)Close','Adj Close':'(DOGE)Adj Close','Volume':'(DOGE)Volume'})

# %%
DOGE_rd.head()
# Out:
#               (DOGE)Open    (DOGE)High     (DOGE)Low   (DOGE)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (DOGE)Adj Close  (DOGE)Volume
# Date
# 2024-06-17     66490.296875   30006354476
# 2024-06-18     65140.746094   39481285950
# 2024-06-19     64960.296875   21103423504
# 2024-06-20     64828.656250   25641109124
# 2024-06-21     64096.199219   26188171739

# %%
XLM_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
XLM_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
XLM_rd = XLM_h.rename(columns={'Open':'(XLM)Open','High':'(XLM)High','Low':'(XLM)Low','Close':'(XLM)Close','Adj Close':'(XLM)Adj Close','Volume':'(XLM)Volume'})

# %%
XLM_rd.head()
# Out:
#                (XLM)Open     (XLM)High      (XLM)Low    (XLM)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (XLM)Adj Close  (XLM)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
SOL_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
SOL_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
SOL_rd = SOL_h.rename(columns={'Open':'(SOL)Open','High':'(SOL)High','Low':'(SOL)Low','Close':'(SOL)Close','Adj Close':'(SOL)Adj Close','Volume':'(SOL)Volume'})

# %%
SOL_rd.head()
# Out:
#                (SOL)Open     (SOL)High      (SOL)Low    (SOL)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (SOL)Adj Close  (SOL)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
USDT_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
USDT_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
USDT_rd = USDT_h.rename(columns={'Open':'(USDT)Open','High':'(USDT)High','Low':'(USDT)Low','Close':'(USDT)Close','Adj Close':'(USDT)Adj Close','Volume':'(USDT)Volume'})

# %%
USDT_rd.head()
# Out:
#               (USDT)Open    (USDT)High     (USDT)Low   (USDT)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (USDT)Adj Close  (USDT)Volume
# Date
# 2024-06-17     66490.296875   30006354476
# 2024-06-18     65140.746094   39481285950
# 2024-06-19     64960.296875   21103423504
# 2024-06-20     64828.656250   25641109124
# 2024-06-21     64096.199219   26188171739

# %%
UNI_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
UNI_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
UNI_rd = UNI_h.rename(columns={'Open':'(UNI)Open','High':'(UNI)High','Low':'(UNI)Low','Close':'(UNI)Close','Adj Close':'(UNI)Adj Close','Volume':'(UNI)Volume'})

# %%
UNI_rd.head()
# Out:
#                (UNI)Open     (UNI)High      (UNI)Low    (UNI)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (UNI)Adj Close  (UNI)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
LINK_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
LINK_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
LINK_rd = LINK_h.rename(columns={'Open':'(LINK)Open','High':'(LINK)High','Low':'(LINK)Low','Close':'(LINK)Close','Adj Close':'(LINK)Adj Close','Volume':'(LINK)Volume'})

# %%
LINK_rd.head()
# Out:
#               (LINK)Open    (LINK)High     (LINK)Low   (LINK)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (LINK)Adj Close  (LINK)Volume
# Date
# 2024-06-17     66490.296875   30006354476
# 2024-06-18     65140.746094   39481285950
# 2024-06-19     64960.296875   21103423504
# 2024-06-20     64828.656250   25641109124
# 2024-06-21     64096.199219   26188171739

# %%
AVAX_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
AVAX_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
AVAX_rd = AVAX_h.rename(columns={'Open':'(AVAX)Open','High':'(AVAX)High','Low':'(AVAX)Low','Close':'(AVAX)Close','Adj Close':'(AVAX)Adj Close','Volume':'(AVAX)Volume'})

# %%
AVAX_rd = AVAX_h.rename(columns={'Open':'(AVAX)Open','High':'(AVAX)High','Low':'(AVAX)Low','Close':'(AVAX)Close','Adj Close':'(AVAX)Adj Close','Volume':'(AVAX)Volume'})

# %%
AVAX_rd.head()
# Out:
#               (AVAX)Open    (AVAX)High     (AVAX)Low   (AVAX)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (AVAX)Adj Close  (AVAX)Volume
# Date
# 2024-06-17     66490.296875   30006354476
# 2024-06-18     65140.746094   39481285950
# 2024-06-19     64960.296875   21103423504
# 2024-06-20     64828.656250   25641109124
# 2024-06-21     64096.199219   26188171739

# %%
BTC_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
BTC_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
XRP_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume
# Date
# 2024-06-17  66490.296875  30006354476
# 2024-06-18  65140.746094  39481285950
# 2024-06-19  64960.296875  21103423504
# 2024-06-20  64828.656250  25641109124
# 2024-06-21  64096.199219  26188171739

# %%
XRP_h.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#                Adj Close        Volume
# Date
# 2024-08-01  65357.500000   40975554494
# 2024-08-02  61415.066406   43060875727
# 2024-08-03  60680.093750   31753030589
# 2024-08-04  58116.976562   31758917219
# 2024-08-05  53991.457031  108991085584

# %%
XRP_rd = XRP_h.rename(columns={'Open':'(XRP)Open','High':'(XRP)High','Low':'(XRP)Low','Close':'(XRP)Close','Adj Close':'(XRP)Adj Close','Volume':'(XRP)Volume'})

# %%
XRP_rd.head()
# Out:
#                (XRP)Open     (XRP)High      (XRP)Low    (XRP)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (XRP)Adj Close  (XRP)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
PREV = pd.read_csv('../CRIPTO/DATASETS/BTC_USD.csv')

# %%
PREV.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2024-06-17  66636.515625  67188.320313  65094.964844  66490.296875
# 1  2024-06-18  66490.976563  66556.703125  64066.957031  65140.746094
# 2  2024-06-19  65146.660156  65695.351563  64693.300781  64960.296875
# 3  2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 4  2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#       Adj Close       Volume
# 0  66490.296875  30006354476
# 1  65140.746094  39481285950
# 2  64960.296875  21103423504
# 3  64828.656250  25641109124
# 4  64096.199219  26188171739

# %%
desired_columns = ['Date']
pre_lnch = PREV[desired_columns]
pre_lnch.head()
# Out:
#          Date
# 0  2024-06-17
# 1  2024-06-18
# 2  2024-06-19
# 3  2024-06-20
# 4  2024-06-21

# %%
pre_lnch.tail()
# Out:
#           Date
# 45  2024-08-01
# 46  2024-08-02
# 47  2024-08-03
# 48  2024-08-04
# 49  2024-08-05

# %%
ETH_rd.head()
# Out:
#                (ETH)Open     (ETH)High      (ETH)Low    (ETH)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (ETH)Adj Close  (ETH)Volume
# Date
# 2024-06-17    66490.296875  30006354476
# 2024-06-18    65140.746094  39481285950
# 2024-06-19    64960.296875  21103423504
# 2024-06-20    64828.656250  25641109124
# 2024-06-21    64096.199219  26188171739

# %%
BTC_h.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']] = ETH_rd.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']]

# %%
BTC_h.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#                Adj Close       Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-06-17  66490.296875  30006354476  66636.515625  67188.320312
# 2024-06-18  65140.746094  39481285950  66490.976562  66556.703125
# 2024-06-19  64960.296875  21103423504  65146.660156  65695.351562
# 2024-06-20  64828.656250  25641109124  64960.296875  66438.960938
# 2024-06-21  64096.199219  26188171739  64837.988281  65007.546875
#
#                 (ETH)Low    (ETH)Close  (ETH)Adj Close  (ETH)Volume
# Date
# 2024-06-17  65094.964844  66490.296875    66490.296875  30006354476
# ...

# %%
launcher_2 = BTC_h.rename(columns={'Open':'(BTC)Open','High':'(BTC)High','Low':'(BTC)Low','Close':'(BTC)Close','Adj Close':'(BTC)Adj Close','Volume':'(BTC)Volume'})

# %%
launcher_2.head()
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
# 2024-06-18  66490.976562  66556.703125  64066.957031  65140.746094
# 2024-06-19  65146.660156  65695.351562  64693.300781  64960.296875
# 2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
# 2024-06-21  64837.988281  65007.546875  63378.894531  64096.199219
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-06-17    66490.296875  30006354476  66636.515625  67188.320312
# 2024-06-18    65140.746094  39481285950  66490.976562  66556.703125
# 2024-06-19    64960.296875  21103423504  65146.660156  65695.351562
# 2024-06-20    64828.656250  25641109124  64960.296875  66438.960938
# 2024-06-21    64096.199219  26188171739  64837.988281  65007.546875
#
#                 (ETH)Low    (ETH)Close  (ETH)Adj Close  (ETH)Volume
# Date
# ...
