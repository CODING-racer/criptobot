# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
NDS = pd.read_csv('../CRIPTO/DATASETS/TAKE_OFF.csv')

# %%
NDS.shape
# Out:
# (19, 90)

# %%
NDS.head()
# Out:
#     (BTC)Open   (BTC)High    (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 0  160.563293  163.595230  155.067032  155.584106      155.584106
# 1  155.591049  161.587158  155.566040  159.072418      159.072418
# 2  159.092331  171.506744  156.606537  169.185867      169.185867
# 3  169.182617  174.831299  167.557312  173.891785      173.891785
# 4  173.893738  184.870316  171.118210  184.541611      184.541611
#
#    (BTC)Volume   (ETH)Open   (ETH)High    (ETH)Low  (ETH)Close  ...  \
# 0   2255652667  160.563293  163.595230  155.067032  155.584106  ...
# 1   2044591406  155.591049  161.587158  155.566040  159.072418  ...
# 2   3617009839  159.092331  171.506744  156.606537  169.185867  ...
# 3   1908476088  169.182617  174.831299  167.557312  173.891785  ...
# 4   3080452915  173.893738  184.870316  171.118210  184.541611  ...
#
#     (LINK)Low  (LINK)Close  (LINK)Adj Close  (LINK)Volume  (AVAX)Open  \
# 0  155.067032   155.584106       155.584106    2255652667    0.124933
# ...

# %%
NDS.tail()
# Out:
#      (BTC)Open   (BTC)High    (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 14  179.108047  184.179443  171.819199  171.826157      171.826157
# 15  171.825668  172.689804  157.988388  167.672119      167.672119
# 16  167.660538  169.043961  150.084991  152.638229      152.638229
# 17  152.638229  153.776855  140.221405  142.921997      142.921997
# 18  142.921951  145.837662  132.139679  138.055084      138.055084
#
#     (BTC)Volume   (ETH)Open   (ETH)High    (ETH)Low  (ETH)Close  ...  \
# 14   3055204208  179.108047  184.179443  171.819199  171.826157  ...
# 15   4402828194  171.825668  172.689804  157.988388  167.672119  ...
# 16   4507521137  167.660538  169.043961  150.084991  152.638229  ...
# 17   3620526646  152.638229  153.776855  140.221405  142.921997  ...
# 18   4333596296  142.921951  145.837662  132.139679  138.055084  ...
#
#      (LINK)Low  (LINK)Close  (LINK)Adj Close  (LINK)Volume  (AVAX)Open  \
# 14  171.819199   171.826157       171.826157    3055204208    0.125593
# ...

# %%
type(NDS)
# Out:
# pandas.core.frame.DataFrame

# %%
NDS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 90 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (BTC)Open        19 non-null     float64
#  1   (BTC)High        19 non-null     float64
#  2   (BTC)Low         19 non-null     float64
#  3   (BTC)Close       19 non-null     float64
#  4   (BTC)Adj Close   19 non-null     float64
#  5   (BTC)Volume      19 non-null     int64
#  6   (ETH)Open        19 non-null     float64
#  7   (ETH)High        19 non-null     float64
#  8   (ETH)Low         19 non-null     float64
#  9   (ETH)Close       19 non-null     float64
#  10  (ETH)Adj Close   19 non-null     float64
#  11  (ETH)Volume      19 non-null     int64
#  12  (XRP)Open        19 non-null     float64
#  13  (XRP)High        19 non-null     float64
#  14  (XRP)Low         19 non-null     float64
#  15  (XRP)Close       19 non-null     float64
# ...

# %%
NDS.dtypes
# Out:
# (BTC)Open          float64
# (BTC)High          float64
# (BTC)Low           float64
# (BTC)Close         float64
# (BTC)Adj Close     float64
#                     ...
# (AVAX)High         float64
# (AVAX)Low          float64
# (AVAX)Close        float64
# (AVAX)Adj Close    float64
# (AVAX)Volume         int64
# Length: 90, dtype: object

# %%
all_columns_list = NDS.columns.values.tolist()
all_columns_list
# Out:
# ['(BTC)Open',
#  '(BTC)High',
#  '(BTC)Low',
#  '(BTC)Close',
#  '(BTC)Adj Close',
#  '(BTC)Volume',
#  '(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume',
#  '(XRP)Open',
#  '(XRP)High',
#  '(XRP)Low',
#  '(XRP)Close',
#  '(XRP)Adj Close',
#  '(XRP)Volume',
#  '(LTC)Open',
#  '(LTC)High',
#  '(LTC)Low',
#  '(LTC)Close',
#  '(LTC)Adj Close',
#  '(LTC)Volume',
#  '(BCH)Open',
#  '(BCH)High',
#  '(BCH)Low',
#  '(BCH)Close',
#  '(BCH)Adj Close',
#  '(BCH)Volume',
#  '(ADA)Open',
#  '(ADA)High',
#  '(ADA)Low',
#  '(ADA)Close',
#  '(ADA)Adj Close',
#  '(ADA)Volume',
#  '(DOT)Open',
#  '(DOT)High',
#  '(DOT)Low',
#  '(DOT)Close',
#  '(DOT)Adj Close',
#  '(DOT)Volume',
#  '(BNB)Open',
#  '(BNB)High',
#  '(BNB)Low',
#  '(BNB)Close',
#  '(BNB)Adj Close',
#  '(BNB)Volume',
#  '(DOGE)Open',
#  '(DOGE)High',
#  '(DOGE)Low',
#  '(DOGE)Close',
#  '(DOGE)Adj Close',
#  '(DOGE)Volume',
#  '(XLM)Open',
#  '(XLM)High',
#  '(XLM)Low',
#  '(XLM)Close',
# ...
