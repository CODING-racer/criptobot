# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_01A = pd.read_csv('CRIPTOS.csv')

# %%
df_01A.head(31)
# Out:
#     (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 0    0.136576   0.137347  0.134819    0.136937        0.136937    385407083
# 1    0.136940   0.138023  0.126495    0.128889        0.128889    960646592
# 2    0.128866   0.129103  0.115392    0.122296        0.122296   1413960450
# 3    0.122279   0.126508  0.121579    0.122341        0.122341    642487745
# 4    0.122341   0.128266  0.121454    0.124419        0.124419    734399819
# 5    0.124430   0.125500  0.121617    0.124029        0.124029    598393023
# 6    0.124038   0.125365  0.122959    0.123789        0.123789    328642106
# 7    0.123783   0.126120  0.121827    0.122257        0.122257    429188641
# 8    0.122249   0.123675  0.114731    0.119043        0.119043    951099440
# 9    0.119033   0.128236  0.118895    0.126153        0.126153    783244352
# 10   0.126150   0.128522  0.121920    0.122679        0.122679    526276880
# ...

# %%
df_01A.tail()
# Out:
#     (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 31   0.124933   0.127506  0.120643    0.121884        0.121884    731025036
# 32   0.121879   0.123843  0.117573    0.119496        0.119496    710080580
# 33   0.119501   0.126056  0.117908    0.125480        0.125480    724349409
# 34   0.125475   0.135646  0.124485    0.134430        0.134430   1109519614
# 35   0.134430   0.134462  0.130084    0.130900        0.130900    737667328
#
#     (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  (LINK)Low  (LINK)Close  \
# 31   0.124933   0.127506  0.120643    0.121884  ...        NaN          NaN
# 32   0.121879   0.123843  0.117573    0.119496  ...        NaN          NaN
# 33   0.119501   0.126056  0.117908    0.125480  ...        NaN          NaN
# 34   0.125475   0.135646  0.124485    0.134430  ...        NaN          NaN
# 35   0.134430   0.134462  0.130084    0.130900  ...        NaN          NaN
#
# ...

# %%
df_01A.shape
# Out:
# (36, 90)

# %%
df_01A.describe()
# Out:
#        (BTC)Open  (BTC)High   (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# count  36.000000  36.000000  36.000000   36.000000       36.000000
# mean    0.119913   0.123153   0.116177    0.119762        0.119762
# std     0.008865   0.008364   0.009090    0.008606        0.008606
# min     0.104235   0.106418   0.093795    0.104232        0.104232
# 25%     0.113270   0.115891   0.107163    0.113300        0.113300
# 50%     0.122310   0.125358   0.119133    0.122318        0.122318
# 75%     0.124954   0.128011   0.121850    0.124952        0.124952
# max     0.136940   0.138023   0.134819    0.136937        0.136937
#
#         (BTC)Volume  (ETH)Open  (ETH)High   (ETH)Low  (ETH)Close  ...  \
# count  3.600000e+01  36.000000  36.000000  36.000000   36.000000  ...
# mean   7.145570e+08   0.119913   0.123153   0.116177    0.119762  ...
# std    3.096280e+08   0.008865   0.008364   0.009090    0.008606  ...
# min    2.853912e+08   0.104235   0.106418   0.093795    0.104232  ...
# ...

# %%
df_01A.plot(kind="scatter", x="(BTC)Open", y="(BTC)Volume")
# Out:
# <AxesSubplot:xlabel='(BTC)Open', ylabel='(BTC)Volume'>

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
df_01A.plot(kind="scatter", x="(BTC)Open", y ="(BTC)Volume", ax=axs[0][0])
df_01A.plot(kind="scatter", x="(ETH)Open", y="(ETH)Volume", ax=axs[0][1])
df_01A.plot(kind="scatter", x="(XRP)Open", y ="(XRP)Volume", ax=axs[1][0])
df_01A.plot(kind="scatter", x="(LTC)Open", y="(LTC)Volume", ax=axs[1][1])
# Out:
# <AxesSubplot:xlabel='(LTC)Open', ylabel='(LTC)Volume'>

# %%
k = int(np.ceil(1+np.log2(3333)))
plt.hist(df_01A["(BTC)High"], bins = k) #bins = [0,30,60,...,200]
plt.xlabel("")
plt.ylabel("Frecuencia")
plt.title("")
# Out:
# Text(0.5, 1.0, '')

# %%
plt.boxplot(df_01A["(BTC)High"])
plt.ylabel("")
plt.title("")
# Out:
# Text(0.5, 1.0, '')

# %%
df_01A["(BTC)High"].describe()
# Out:
# count    36.000000
# mean      0.123153
# std       0.008364
# min       0.106418
# 25%       0.115891
# 50%       0.125358
# 75%       0.128011
# max       0.138023
# Name: (BTC)High, dtype: float64

# %%
df_01A[:31]
# Out:
#     (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 0    0.136576   0.137347  0.134819    0.136937        0.136937    385407083
# 1    0.136940   0.138023  0.126495    0.128889        0.128889    960646592
# 2    0.128866   0.129103  0.115392    0.122296        0.122296   1413960450
# 3    0.122279   0.126508  0.121579    0.122341        0.122341    642487745
# 4    0.122341   0.128266  0.121454    0.124419        0.124419    734399819
# 5    0.124430   0.125500  0.121617    0.124029        0.124029    598393023
# 6    0.124038   0.125365  0.122959    0.123789        0.123789    328642106
# 7    0.123783   0.126120  0.121827    0.122257        0.122257    429188641
# 8    0.122249   0.123675  0.114731    0.119043        0.119043    951099440
# 9    0.119033   0.128236  0.118895    0.126153        0.126153    783244352
# 10   0.126150   0.128522  0.121920    0.122679        0.122679    526276880
# ...

# %%
CC = pd.read_csv('CRIPTOS_A.csv')

# %%
CC.head()
# Out:
#    (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 0   0.136940   0.138023  0.126495    0.128889        0.128889    960646592
# 1   0.128866   0.129103  0.115392    0.122296        0.122296   1413960450
# 2   0.122279   0.126508  0.121579    0.122341        0.122341    642487745
# 3   0.122341   0.128266  0.121454    0.124419        0.124419    734399819
# 4   0.124430   0.125500  0.121617    0.124029        0.124029    598393023
#
#    (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  (LINK)Low  (LINK)Close  \
# 0   0.136940   0.138023  0.126495    0.128889  ...  14.062859    14.534426
# 1   0.128866   0.129103  0.115392    0.122296  ...  13.119523    13.967771
# 2   0.122279   0.126508  0.121579    0.122341  ...  13.924068    14.334752
# 3   0.122341   0.128266  0.121454    0.124419  ...  14.209382    14.259184
# 4   0.124430   0.125500  0.121617    0.124029  ...  13.862212    13.862212
#
# ...

# %%
CC.shape
# Out:
# (30, 90)

# %%
type(CC)
# Out:
# pandas.core.frame.DataFrame

# %%
CC.dtypes
# Out:
# (BTC)Open          float64
# (BTC)High          float64
# (BTC)Low           float64
# (BTC)Close         float64
# (BTC)Adj Close     float64
#                     ...
# (AVAX)High         float64
# (AVAX)Low          float64
# (AVAX)Close        float64
# (AVAX)Adj Close    float64
# (AVAX)Volume         int64
# Length: 90, dtype: object

# %%
CC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 90 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (BTC)Open        30 non-null     float64
#  1   (BTC)High        30 non-null     float64
#  2   (BTC)Low         30 non-null     float64
#  3   (BTC)Close       30 non-null     float64
#  4   (BTC)Adj Close   30 non-null     float64
#  5   (BTC)Volume      30 non-null     int64
#  6   (ETH)Open        30 non-null     float64
#  7   (ETH)High        30 non-null     float64
#  8   (ETH)Low         30 non-null     float64
#  9   (ETH)Close       30 non-null     float64
#  10  (ETH)Adj Close   30 non-null     float64
#  11  (ETH)Volume      30 non-null     int64
#  12  (XRP)Open        30 non-null     float64
#  13  (XRP)High        30 non-null     float64
#  14  (XRP)Low         30 non-null     float64
#  15  (XRP)Close       30 non-null     float64
# ...

# %%
BTC = pd.read_csv('../CRIPTO/Datasets/BTC-USD.csv')
BTC.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2024-06-16  66189.359375  66894.843750  66018.250000  66639.046875
# 1  2024-06-17  66636.515625  67188.320313  65094.964844  66490.296875
# 2  2024-06-18  66490.976563  66556.703125  64066.957031  65140.746094
# 3  2024-06-19  65146.660156  65695.351563  64693.300781  64960.296875
# 4  2024-06-20  64960.296875  66438.960938  64547.847656  64828.656250
#
#       Adj Close       Volume
# 0  66639.046875  13281140541
# 1  66490.296875  30006354476
# 2  65140.746094  39481285950
# 3  64960.296875  21103423504
# 4  64828.656250  25641109124

# %%
BTC.shape
# Out:
# (31, 7)

# %%
desire_columns = ['Date']
launcher = BTC[desire_columns]
launcher.head()
# Out:
#          Date
# 0  2024-06-16
# 1  2024-06-17
# 2  2024-06-18
# 3  2024-06-19
# 4  2024-06-20

# %%
launcher.shape
# Out:
# (31, 1)

# %%
launcher.dtypes
# Out:
# Date    object
# dtype: object

# %%
type(launcher)
# Out:
# pandas.core.frame.DataFrame

# %%
launcher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    31 non-null     object
# dtypes: object(1)
# memory usage: 376.0+ bytes

# %%
CC.loc[:,['Date']] = launcher.loc[:,['Date'] ]

# %%
CC.head()
# Out:
#    (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 0   0.136940   0.138023  0.126495    0.128889        0.128889    960646592
# 1   0.128866   0.129103  0.115392    0.122296        0.122296   1413960450
# 2   0.122279   0.126508  0.121579    0.122341        0.122341    642487745
# 3   0.122341   0.128266  0.121454    0.124419        0.124419    734399819
# 4   0.124430   0.125500  0.121617    0.124029        0.124029    598393023
#
#    (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  (LINK)Close  \
# 0   0.136940   0.138023  0.126495    0.128889  ...    14.534426
# 1   0.128866   0.129103  0.115392    0.122296  ...    13.967771
# 2   0.122279   0.126508  0.121579    0.122341  ...    14.334752
# 3   0.122341   0.128266  0.121454    0.124419  ...    14.259184
# 4   0.124430   0.125500  0.121617    0.124029  ...    13.862212
#
#    (LINK)Adj Close  (LINK)Volume  (AVAX)Open  (AVAX)High  (AVAX)Low  \
# ...

# %%
all_columns_list = CC.columns.values.tolist()
all_columns_list
# Out:
# ['(BTC)Open',
#  '(BTC)High',
#  '(BTC)Low',
#  '(BTC)Close',
#  '(BTC)Adj Close',
#  '(BTC)Volume',
#  '(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume',
#  '(XRP)Open',
#  '(XRP)High',
#  '(XRP)Low',
#  '(XRP)Close',
#  '(XRP)Adj Close',
#  '(XRP)Volume',
#  '(LTC)Open',
#  '(LTC)High',
#  '(LTC)Low',
#  '(LTC)Close',
#  '(LTC)Adj Close',
#  '(LTC)Volume',
#  '(BCH)Open',
#  '(BCH)High',
#  '(BCH)Low',
#  '(BCH)Close',
#  '(BCH)Adj Close',
#  '(BCH)Volume',
#  '(ADA)Open',
#  '(ADA)High',
#  '(ADA)Low',
#  '(ADA)Close',
#  '(ADA)Adj Close',
#  '(ADA)Volume',
#  '(DOT)Open',
#  '(DOT)High',
#  '(DOT)Low',
#  '(DOT)Close',
#  '(DOT)Adj Close',
#  '(DOT)Volume',
#  '(BNB)Open',
#  '(BNB)High',
#  '(BNB)Low',
#  '(BNB)Close',
#  '(BNB)Adj Close',
#  '(BNB)Volume',
#  '(DOGE)Open',
#  '(DOGE)High',
#  '(DOGE)Low',
#  '(DOGE)Close',
#  '(DOGE)Adj Close',
#  '(DOGE)Volume',
#  '(XLM)Open',
#  '(XLM)High',
#  '(XLM)Low',
#  '(XLM)Close',
# ...

# %%
column_order = ['Date','(BTC)Open',
 '(BTC)High',
 '(BTC)Low',
 '(BTC)Close',
 '(BTC)Adj Close',
 '(BTC)Volume',
 '(ETH)Open',
 '(ETH)High',
 '(ETH)Low',
 '(ETH)Close',
 '(ETH)Adj Close',
 '(ETH)Volume',
 '(XRP)Open',
 '(XRP)High',
 '(XRP)Low',
 '(XRP)Close',
 '(XRP)Adj Close',
 '(XRP)Volume',
 '(LTC)Open',
 '(LTC)High',
 '(LTC)Low',
 '(LTC)Close',
 '(LTC)Adj Close',
 '(LTC)Volume',
 '(BCH)Open',
 '(BCH)High',
 '(BCH)Low',
 '(BCH)Close',
 '(BCH)Adj Close',
 '(BCH)Volume',
 '(ADA)Open',
 '(ADA)High',
 '(ADA)Low',
 '(ADA)Close',
 '(ADA)Adj Close',
 '(ADA)Volume',
 '(DOT)Open',
 '(DOT)High',
 '(DOT)Low',
 '(DOT)Close',
 '(DOT)Adj Close',
 '(DOT)Volume',
 '(BNB)Open',
 '(BNB)High',
 '(BNB)Low',
 '(BNB)Close',
 '(BNB)Adj Close',
 '(BNB)Volume',
 '(DOGE)Open',
 '(DOGE)High',
 '(DOGE)Low',
 '(DOGE)Close',
 '(DOGE)Adj Close',
 '(DOGE)Volume',
 '(XLM)Open',
 '(XLM)High',
 '(XLM)Low',
 '(XLM)Close',
 '(XLM)Adj Close',
 '(XLM)Volume',
 '(SOL)Open',
 '(SOL)High',
 '(SOL)Low',
 '(SOL)Close',
 '(SOL)Adj Close',
 '(SOL)Volume',
 '(USDT)Open',
 '(USDT)High',
 '(USDT)Low',
 '(USDT)Close',
 '(USDT)Adj Close',
 '(USDT)Volume',
 '(UNI)Open',
 '(UNI)High',
 '(UNI)Low',
 '(UNI)Close',
 '(UNI)Adj Close',
 '(UNI)Volume',
 '(LINK)Open',
 '(LINK)High',
 '(LINK)Low',
 '(LINK)Close',
 '(LINK)Adj Close',
 '(LINK)Volume',
 '(AVAX)Open',
 '(AVAX)High',
 '(AVAX)Low',
 '(AVAX)Close',
 '(AVAX)Adj Close',
 '(AVAX)Volume']
CC = CC[column_order]

# %%
CC.head()
# Out:
#          Date  (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 0  2024-06-16   0.136940   0.138023  0.126495    0.128889        0.128889
# 1  2024-06-17   0.128866   0.129103  0.115392    0.122296        0.122296
# 2  2024-06-18   0.122279   0.126508  0.121579    0.122341        0.122341
# 3  2024-06-19   0.122341   0.128266  0.121454    0.124419        0.124419
# 4  2024-06-20   0.124430   0.125500  0.121617    0.124029        0.124029
#
#    (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  ...  (LINK)Low  (LINK)Close  \
# 0    960646592   0.136940   0.138023  0.126495  ...  14.062859    14.534426
# 1   1413960450   0.128866   0.129103  0.115392  ...  13.119523    13.967771
# 2    642487745   0.122279   0.126508  0.121579  ...  13.924068    14.334752
# 3    734399819   0.122341   0.128266  0.121454  ...  14.209382    14.259184
# 4    598393023   0.124430   0.125500  0.121617  ...  13.862212    13.862212
#
# ...

# %%
CC.tail()
# Out:
#           Date  (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 25  2024-07-11   0.106664   0.108266  0.105032    0.107685        0.107685
# 26  2024-07-12   0.107685   0.112889  0.107447    0.112356        0.112356
# 27  2024-07-13   0.112350   0.116495  0.111350    0.115449        0.115449
# 28  2024-07-14   0.115471   0.125352  0.114789    0.125228        0.125228
# 29  2024-07-15   0.125164   0.127257  0.119371    0.124931        0.124931
#
#     (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  ...  (LINK)Low  (LINK)Close  \
# 25    468503073   0.106664   0.108266  0.105032  ...  12.251700    12.738323
# 26    497448463   0.107685   0.112889  0.107447  ...  12.717275    13.021287
# 27    551768272   0.112350   0.116495  0.111350  ...  12.918180    13.426870
# 28    865334768   0.115471   0.125352  0.114789  ...  13.423407    14.422127
# 29   1023424280   0.125164   0.127257  0.119371  ...        NaN          NaN
#
# ...

# %%
CC.shape
# Out:
# (30, 91)

# %%
CC.to_csv('../CRIPTO/Datasets/C_Coins.csv', index=False)

# %%
DATA = pd.read_csv('../CRIPTO/Datasets/BTC-NUEVO.csv')

# %%
DATA.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2023-07-17  30249.626953  30336.400391  29685.783203  30145.888672
# 1  2023-07-18  30147.070313  30233.656250  29556.427734  29856.562500
# 2  2023-07-19  29862.046875  30184.181641  29794.269531  29913.923828
# 3  2023-07-20  29915.250000  30195.531250  29638.095703  29792.015625
# 4  2023-07-21  29805.111328  30045.998047  29733.851563  29908.744141
#
#       Adj Close       Volume
# 0  30145.888672  13240156074
# 1  29856.562500  13138897269
# 2  29913.923828  12128602812
# 3  29792.015625  14655207121
# 4  29908.744141  10972789818

# %%
DATA.tail()
# Out:
#            Date          Open          High           Low         Close  \
# 381  2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 382  2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 383  2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 384  2024-08-04  60676.093750  61062.988281  57210.804688  58116.976563
# 385  2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
#
#         Adj Close        Volume
# 381  65357.500000   40975554494
# 382  61415.066406   43060875727
# 383  60680.093750   31753030589
# 384  58116.976563   31758917219
# 385  53991.457031  108991085584

# %%
DATA.shape
# Out:
# (386, 7)

# %%
DATA_1 = pd.read_csv('../CRIPTO/Datasets/again.csv')

# %%
DATA_1.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2023-07-17  30249.626953  30336.400391  29685.783203  30145.888672
# 1  2023-07-18  30147.070313  30233.656250  29556.427734  29856.562500
# 2  2023-07-19  29862.046875  30184.181641  29794.269531  29913.923828
# 3  2023-07-20  29915.250000  30195.531250  29638.095703  29792.015625
# 4  2023-07-21  29805.111328  30045.998047  29733.851563  29908.744141
#
#       Adj Close       Volume
# 0  30145.888672  13240156074
# 1  29856.562500  13138897269
# 2  29913.923828  12128602812
# 3  29792.015625  14655207121
# 4  29908.744141  10972789818

# %%
DATA_1.tail()
# Out:
#            Date          Open          High           Low         Close  \
# 380  2024-07-31  66201.273438  66810.210938  64532.046875  64619.250000
# 381  2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 382  2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 383  2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 384  2024-08-04  60676.093750  61062.988281  57210.804688  58116.976563
#
#         Adj Close       Volume
# 380  64619.250000  31292785994
# 381  65357.500000  40975554494
# 382  61415.066406  43060875727
# 383  60680.093750  31753030589
# 384  58116.976563  31758917219

# %%
DATA_1.shape
# Out:
# (385, 7)

# %%
desire_columns = ['Date']
lanzadera = DATA_1[desire_columns]
lanzadera.head()
# Out:
#          Date
# 0  2023-07-17
# 1  2023-07-18
# 2  2023-07-19
# 3  2023-07-20
# 4  2023-07-21

# %%
pre = pd.read_csv('../CRIPTO/Datasets/TAKE_OFF.csv')

# %%
pre.head()
# Out:
#     (BTC)Open   (BTC)High    (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 0  160.563293  163.595230  155.067032  155.584106      155.584106
# 1  155.591049  161.587158  155.566040  159.072418      159.072418
# 2  159.092331  171.506744  156.606537  169.185867      169.185867
# 3  169.182617  174.831299  167.557312  173.891785      173.891785
# 4  173.893738  184.870316  171.118210  184.541611      184.541611
#
#    (BTC)Volume   (ETH)Open   (ETH)High    (ETH)Low  (ETH)Close  ...  \
# 0   2255652667  160.563293  163.595230  155.067032  155.584106  ...
# 1   2044591406  155.591049  161.587158  155.566040  159.072418  ...
# 2   3617009839  159.092331  171.506744  156.606537  169.185867  ...
# 3   1908476088  169.182617  174.831299  167.557312  173.891785  ...
# 4   3080452915  173.893738  184.870316  171.118210  184.541611  ...
#
#     (LINK)Low  (LINK)Close  (LINK)Adj Close  (LINK)Volume  (AVAX)Open  \
# 0  155.067032   155.584106       155.584106    2255652667    0.124933
# ...

# %%
pre.shape
# Out:
# (19, 90)

# %%
lanzadera.shape
# Out:
# (385, 1)

# %%
DATA_2 = pd.read_csv('../CRIPTO/Datasets/new_again.csv')

# %%
DATA_2.shape
# Out:
# (19, 7)

# %%
DATA_2.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2024-07-17  65091.832031  66066.734375  63896.085938  64118.792969
# 1  2024-07-18  64104.738281  65104.660156  63246.164063  63974.066406
# 2  2024-07-19  63972.324219  67442.640625  63329.343750  66710.156250
# 3  2024-07-20  66709.921875  67610.734375  66299.617188  67163.648438
# 4  2024-07-21  67164.914063  68372.906250  65842.296875  68154.523438
#
#       Adj Close       Volume
# 0  64118.792969  32525071311
# 1  63974.066406  27239305337
# 2  66710.156250  37003855410
# 3  67163.648438  19029581250
# 4  68154.523438  26652190004

# %%
DATA_2.tail()
# Out:
#           Date          Open          High           Low         Close  \
# 14  2024-07-31  66201.273438  66810.210938  64532.046875  64619.250000
# 15  2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 16  2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 17  2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 18  2024-08-04  60676.093750  61062.988281  57210.804688  58116.976563
#
#        Adj Close       Volume
# 14  64619.250000  31292785994
# 15  65357.500000  40975554494
# 16  61415.066406  43060875727
# 17  60680.093750  31753030589
# 18  58116.976563  31758917219

# %%
desire_columns = ['Date']
lanzadera_1 = DATA_2[desire_columns]
lanzadera_1.head()
# Out:
#          Date
# 0  2024-07-17
# 1  2024-07-18
# 2  2024-07-19
# 3  2024-07-20
# 4  2024-07-21

# %%
lanzadera_1.tail()
# Out:
#           Date
# 14  2024-07-31
# 15  2024-08-01
# 16  2024-08-02
# 17  2024-08-03
# 18  2024-08-04

# %%
lanzadera_1.shape
# Out:
# (19, 1)

# %%
pre.loc[:,['Date']] = lanzadera_1.loc[:,['Date'] ]

# %%
pre.head()
# Out:
#     (BTC)Open   (BTC)High    (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 0  160.563293  163.595230  155.067032  155.584106      155.584106
# 1  155.591049  161.587158  155.566040  159.072418      159.072418
# 2  159.092331  171.506744  156.606537  169.185867      169.185867
# 3  169.182617  174.831299  167.557312  173.891785      173.891785
# 4  173.893738  184.870316  171.118210  184.541611      184.541611
#
#    (BTC)Volume   (ETH)Open   (ETH)High    (ETH)Low  (ETH)Close  ...  \
# 0   2255652667  160.563293  163.595230  155.067032  155.584106  ...
# 1   2044591406  155.591049  161.587158  155.566040  159.072418  ...
# 2   3617009839  159.092331  171.506744  156.606537  169.185867  ...
# 3   1908476088  169.182617  174.831299  167.557312  173.891785  ...
# 4   3080452915  173.893738  184.870316  171.118210  184.541611  ...
#
#    (LINK)Close  (LINK)Adj Close  (LINK)Volume  (AVAX)Open  (AVAX)High  \
# 0   155.584106       155.584106    2255652667    0.124933    0.127506
# ...

# %%
pre.shape
# Out:
# (19, 91)

# %%
column_order = ['Date','(BTC)Open',
 '(BTC)High',
 '(BTC)Low',
 '(BTC)Close',
 '(BTC)Adj Close',
 '(BTC)Volume',
 '(ETH)Open',
 '(ETH)High',
 '(ETH)Low',
 '(ETH)Close',
 '(ETH)Adj Close',
 '(ETH)Volume',
 '(XRP)Open',
 '(XRP)High',
 '(XRP)Low',
 '(XRP)Close',
 '(XRP)Adj Close',
 '(XRP)Volume',
 '(LTC)Open',
 '(LTC)High',
 '(LTC)Low',
 '(LTC)Close',
 '(LTC)Adj Close',
 '(LTC)Volume',
 '(BCH)Open',
 '(BCH)High',
 '(BCH)Low',
 '(BCH)Close',
 '(BCH)Adj Close',
 '(BCH)Volume',
 '(ADA)Open',
 '(ADA)High',
 '(ADA)Low',
 '(ADA)Close',
 '(ADA)Adj Close',
 '(ADA)Volume',
 '(DOT)Open',
 '(DOT)High',
 '(DOT)Low',
 '(DOT)Close',
 '(DOT)Adj Close',
 '(DOT)Volume',
 '(BNB)Open',
 '(BNB)High',
 '(BNB)Low',
 '(BNB)Close',
 '(BNB)Adj Close',
 '(BNB)Volume',
 '(DOGE)Open',
 '(DOGE)High',
 '(DOGE)Low',
 '(DOGE)Close',
 '(DOGE)Adj Close',
 '(DOGE)Volume',
 '(XLM)Open',
 '(XLM)High',
 '(XLM)Low',
 '(XLM)Close',
 '(XLM)Adj Close',
 '(XLM)Volume',
 '(SOL)Open',
 '(SOL)High',
 '(SOL)Low',
 '(SOL)Close',
 '(SOL)Adj Close',
 '(SOL)Volume',
 '(USDT)Open',
 '(USDT)High',
 '(USDT)Low',
 '(USDT)Close',
 '(USDT)Adj Close',
 '(USDT)Volume',
 '(UNI)Open',
 '(UNI)High',
 '(UNI)Low',
 '(UNI)Close',
 '(UNI)Adj Close',
 '(UNI)Volume',
 '(LINK)Open',
 '(LINK)High',
 '(LINK)Low',
 '(LINK)Close',
 '(LINK)Adj Close',
 '(LINK)Volume',
 '(AVAX)Open',
 '(AVAX)High',
 '(AVAX)Low',
 '(AVAX)Close',
 '(AVAX)Adj Close',
 '(AVAX)Volume']
pre = pre[column_order]

# %%
pre.head()
# Out:
#          Date   (BTC)Open   (BTC)High    (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 0  2024-07-17  160.563293  163.595230  155.067032  155.584106      155.584106
# 1  2024-07-18  155.591049  161.587158  155.566040  159.072418      159.072418
# 2  2024-07-19  159.092331  171.506744  156.606537  169.185867      169.185867
# 3  2024-07-20  169.182617  174.831299  167.557312  173.891785      173.891785
# 4  2024-07-21  173.893738  184.870316  171.118210  184.541611      184.541611
#
#    (BTC)Volume   (ETH)Open   (ETH)High    (ETH)Low  ...   (LINK)Low  \
# 0   2255652667  160.563293  163.595230  155.067032  ...  155.067032
# 1   2044591406  155.591049  161.587158  155.566040  ...  155.566040
# 2   3617009839  159.092331  171.506744  156.606537  ...  156.606537
# 3   1908476088  169.182617  174.831299  167.557312  ...  167.557312
# 4   3080452915  173.893738  184.870316  171.118210  ...  171.118210
#
#    (LINK)Close  (LINK)Adj Close  (LINK)Volume  (AVAX)Open  (AVAX)High  \
# ...

# %%
CC.head()
# Out:
#          Date  (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 0  2024-06-16   0.136940   0.138023  0.126495    0.128889        0.128889
# 1  2024-06-17   0.128866   0.129103  0.115392    0.122296        0.122296
# 2  2024-06-18   0.122279   0.126508  0.121579    0.122341        0.122341
# 3  2024-06-19   0.122341   0.128266  0.121454    0.124419        0.124419
# 4  2024-06-20   0.124430   0.125500  0.121617    0.124029        0.124029
#
#    (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  ...  (LINK)Low  (LINK)Close  \
# 0    960646592   0.136940   0.138023  0.126495  ...  14.062859    14.534426
# 1   1413960450   0.128866   0.129103  0.115392  ...  13.119523    13.967771
# 2    642487745   0.122279   0.126508  0.121579  ...  13.924068    14.334752
# 3    734399819   0.122341   0.128266  0.121454  ...  14.209382    14.259184
# 4    598393023   0.124430   0.125500  0.121617  ...  13.862212    13.862212
#
# ...

# %%
CC.tail()
# Out:
#           Date  (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 25  2024-07-11   0.106664   0.108266  0.105032    0.107685        0.107685
# 26  2024-07-12   0.107685   0.112889  0.107447    0.112356        0.112356
# 27  2024-07-13   0.112350   0.116495  0.111350    0.115449        0.115449
# 28  2024-07-14   0.115471   0.125352  0.114789    0.125228        0.125228
# 29  2024-07-15   0.125164   0.127257  0.119371    0.124931        0.124931
#
#     (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  ...  (LINK)Low  (LINK)Close  \
# 25    468503073   0.106664   0.108266  0.105032  ...  12.251700    12.738323
# 26    497448463   0.107685   0.112889  0.107447  ...  12.717275    13.021287
# 27    551768272   0.112350   0.116495  0.111350  ...  12.918180    13.426870
# 28    865334768   0.115471   0.125352  0.114789  ...  13.423407    14.422127
# 29   1023424280   0.125164   0.127257  0.119371  ...        NaN          NaN
#
# ...

# %%
CC.shape
# Out:
# (30, 91)

# %%
CC
# Out:
#           Date  (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 0   2024-06-16   0.136940   0.138023  0.126495    0.128889        0.128889
# 1   2024-06-17   0.128866   0.129103  0.115392    0.122296        0.122296
# 2   2024-06-18   0.122279   0.126508  0.121579    0.122341        0.122341
# 3   2024-06-19   0.122341   0.128266  0.121454    0.124419        0.124419
# 4   2024-06-20   0.124430   0.125500  0.121617    0.124029        0.124029
# 5   2024-06-21   0.124038   0.125365  0.122959    0.123789        0.123789
# 6   2024-06-22   0.123783   0.126120  0.121827    0.122257        0.122257
# 7   2024-06-23   0.122249   0.123675  0.114731    0.119043        0.119043
# 8   2024-06-24   0.119033   0.128236  0.118895    0.126153        0.126153
# 9   2024-06-25   0.126150   0.128522  0.121920    0.122679        0.122679
# 10  2024-06-26   0.122672   0.128115  0.120630    0.126911        0.126911
# ...

# %%
pre
# Out:
#           Date   (BTC)Open   (BTC)High    (BTC)Low  (BTC)Close  \
# 0   2024-07-17  160.563293  163.595230  155.067032  155.584106
# 1   2024-07-18  155.591049  161.587158  155.566040  159.072418
# 2   2024-07-19  159.092331  171.506744  156.606537  169.185867
# 3   2024-07-20  169.182617  174.831299  167.557312  173.891785
# 4   2024-07-21  173.893738  184.870316  171.118210  184.541611
# 5   2024-07-22  184.545563  184.792465  177.044128  178.978287
# 6   2024-07-23  178.978287  180.496155  170.988541  172.757568
# 7   2024-07-24  172.758514  182.357605  171.210419  178.032303
# 8   2024-07-25  178.029526  179.520935  165.932541  171.963074
# 9   2024-07-26  171.962570  183.538361  171.877899  183.136719
# 10  2024-07-27  183.138092  188.140594  178.598358  184.085403
# 11  2024-07-28  184.085999  186.514618  181.395340  184.886078
# 12  2024-07-29  184.887192  193.732285  181.885361  182.780594
# 13  2024-07-30  182.771591  184.180130  176.022430  179.107193
# ...
