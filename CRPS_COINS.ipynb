# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
CRPS = pd.read_csv('../CRIPTO/Datasets/C_Coins.csv')

# %%
CRPS.head()
# Out:
#          Date  (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# 0  2024-06-16   0.136940   0.138023  0.126495    0.128889        0.128889
# 1  2024-06-17   0.128866   0.129103  0.115392    0.122296        0.122296
# 2  2024-06-18   0.122279   0.126508  0.121579    0.122341        0.122341
# 3  2024-06-19   0.122341   0.128266  0.121454    0.124419        0.124419
# 4  2024-06-20   0.124430   0.125500  0.121617    0.124029        0.124029
#
#    (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  ...  (LINK)Low  (LINK)Close  \
# 0    960646592   0.136940   0.138023  0.126495  ...  14.062859    14.534426
# 1   1413960450   0.128866   0.129103  0.115392  ...  13.119523    13.967771
# 2    642487745   0.122279   0.126508  0.121579  ...  13.924068    14.334752
# 3    734399819   0.122341   0.128266  0.121454  ...  14.209382    14.259184
# 4    598393023   0.124430   0.125500  0.121617  ...  13.862212    13.862212
#
# ...

# %%
CRPS.shape
# Out:
# (30, 91)

# %%
type(CRPS)
# Out:
# pandas.core.frame.DataFrame

# %%
CRPS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 91 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             30 non-null     object
#  1   (BTC)Open        30 non-null     float64
#  2   (BTC)High        30 non-null     float64
#  3   (BTC)Low         30 non-null     float64
#  4   (BTC)Close       30 non-null     float64
#  5   (BTC)Adj Close   30 non-null     float64
#  6   (BTC)Volume      30 non-null     int64
#  7   (ETH)Open        30 non-null     float64
#  8   (ETH)High        30 non-null     float64
#  9   (ETH)Low         30 non-null     float64
#  10  (ETH)Close       30 non-null     float64
#  11  (ETH)Adj Close   30 non-null     float64
#  12  (ETH)Volume      30 non-null     int64
#  13  (XRP)Open        30 non-null     float64
#  14  (XRP)High        30 non-null     float64
#  15  (XRP)Low         30 non-null     float64
# ...

# %%
CRPS.dtypes
# Out:
# Date                object
# (BTC)Open          float64
# (BTC)High          float64
# (BTC)Low           float64
# (BTC)Close         float64
#                     ...
# (AVAX)High         float64
# (AVAX)Low          float64
# (AVAX)Close        float64
# (AVAX)Adj Close    float64
# (AVAX)Volume         int64
# Length: 91, dtype: object

# %%
CRPS.columns.values
# Out:
# array(['Date', '(BTC)Open', '(BTC)High', '(BTC)Low', '(BTC)Close',
#        '(BTC)Adj Close', '(BTC)Volume', '(ETH)Open', '(ETH)High',
#        '(ETH)Low', '(ETH)Close', '(ETH)Adj Close', '(ETH)Volume',
#        '(XRP)Open', '(XRP)High', '(XRP)Low', '(XRP)Close',
#        '(XRP)Adj Close', '(XRP)Volume', '(LTC)Open', '(LTC)High',
#        '(LTC)Low', '(LTC)Close', '(LTC)Adj Close', '(LTC)Volume',
#        '(BCH)Open', '(BCH)High', '(BCH)Low', '(BCH)Close',
#        '(BCH)Adj Close', '(BCH)Volume', '(ADA)Open', '(ADA)High',
#        '(ADA)Low', '(ADA)Close', '(ADA)Adj Close', '(ADA)Volume',
#        '(DOT)Open', '(DOT)High', '(DOT)Low', '(DOT)Close',
#        '(DOT)Adj Close', '(DOT)Volume', '(BNB)Open', '(BNB)High',
#        '(BNB)Low', '(BNB)Close', '(BNB)Adj Close', '(BNB)Volume',
#        '(DOGE)Open', '(DOGE)High', '(DOGE)Low', '(DOGE)Close',
#        '(DOGE)Adj Close', '(DOGE)Volume', '(XLM)Open', '(XLM)High',
#        '(XLM)Low', '(XLM)Close', '(XLM)Adj Close', '(XLM)Volume',
# ...

# %%
all_columns_list = CRPS.columns.values.tolist()
all_columns_list
# Out:
# ['Date',
#  '(BTC)Open',
#  '(BTC)High',
#  '(BTC)Low',
#  '(BTC)Close',
#  '(BTC)Adj Close',
#  '(BTC)Volume',
#  '(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume',
#  '(XRP)Open',
#  '(XRP)High',
#  '(XRP)Low',
#  '(XRP)Close',
#  '(XRP)Adj Close',
#  '(XRP)Volume',
#  '(LTC)Open',
#  '(LTC)High',
#  '(LTC)Low',
#  '(LTC)Close',
#  '(LTC)Adj Close',
#  '(LTC)Volume',
#  '(BCH)Open',
#  '(BCH)High',
#  '(BCH)Low',
#  '(BCH)Close',
#  '(BCH)Adj Close',
#  '(BCH)Volume',
#  '(ADA)Open',
#  '(ADA)High',
#  '(ADA)Low',
#  '(ADA)Close',
#  '(ADA)Adj Close',
#  '(ADA)Volume',
#  '(DOT)Open',
#  '(DOT)High',
#  '(DOT)Low',
#  '(DOT)Close',
#  '(DOT)Adj Close',
#  '(DOT)Volume',
#  '(BNB)Open',
#  '(BNB)High',
#  '(BNB)Low',
#  '(BNB)Close',
#  '(BNB)Adj Close',
#  '(BNB)Volume',
#  '(DOGE)Open',
#  '(DOGE)High',
#  '(DOGE)Low',
#  '(DOGE)Close',
#  '(DOGE)Adj Close',
#  '(DOGE)Volume',
#  '(XLM)Open',
#  '(XLM)High',
#  '(XLM)Low',
# ...

# %%
len(CRPS)
# Out:
# 30

# %%
CRPS.describe()
# Out:
#        (BTC)Open  (BTC)High   (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# count  30.000000  30.000000  30.000000   30.000000       30.000000
# mean    0.118470   0.121622   0.114562    0.118076        0.118076
# std     0.008589   0.008019   0.008668    0.007955        0.007955
# min     0.104235   0.106418   0.093795    0.104232        0.104232
# 25%     0.109106   0.113703   0.106181    0.109105        0.109105
# 50%     0.122264   0.125329   0.117970    0.122276        0.122276
# 75%     0.124237   0.127252   0.121607    0.124236        0.124236
# max     0.136940   0.138023   0.126495    0.128889        0.128889
#
#         (BTC)Volume  (ETH)Open  (ETH)High   (ETH)Low  (ETH)Close  ...  \
# count  3.000000e+01  30.000000  30.000000  30.000000   30.000000  ...
# mean   7.108668e+08   0.118470   0.121622   0.114562    0.118076  ...
# std    3.264103e+08   0.008589   0.008019   0.008668    0.007955  ...
# min    2.853912e+08   0.104235   0.106418   0.093795    0.104232  ...
# ...

# %%
CRPS.plot(kind="scatter", x="(BTC)Open", y="(BTC)Volume")
# Out:
# <AxesSubplot:xlabel='(BTC)Open', ylabel='(BTC)Volume'>

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
CRPS.plot(kind="scatter", x="(BTC)Open", y ="(BTC)Volume", ax=axs[0][0])
CRPS.plot(kind="scatter", x="(ETH)Open", y="(ETH)Volume", ax=axs[0][1])
CRPS.plot(kind="scatter", x="(XRP)Open", y ="(XRP)Volume", ax=axs[1][0])
CRPS.plot(kind="scatter", x="(LTC)Open", y="(LTC)Volume", ax=axs[1][1])
# Out:
# <AxesSubplot:xlabel='(LTC)Open', ylabel='(LTC)Volume'>

# %%
k = int(np.ceil(1+np.log2(3333)))
plt.hist(CRPS["(BTC)High"], bins = k) #bins = [0,30,60,...,200]
plt.xlabel("")
plt.ylabel("Frecuencia")
plt.title("")
# Out:
# Text(0.5, 1.0, '')

# %%
plt.boxplot(CRPS["(BTC)High"])
plt.ylabel("")
plt.title("")
# Out:
# Text(0.5, 1.0, '')
