# %% [markdown]
# <a href="https://colab.research.google.com/github/CODING-racer/criptobot/blob/main/lafe0001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd

# %% [markdown]
# # Nueva sección

# %%
dtf = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/titanic3.csv')
dtf
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
dtf01 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sales_train.csv')
dtf01
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
dtf02 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PANDAS/La_Fe_de_Cuiculco.csv')
dtf02
# Out:
#                  Sku                                     Name  Marca  \
# 0    2085B603G029366                      Estopa Algodón 1 kg    FOY
# 1    2085B603G029553            Cinta Sella Roscas 1/2" x 7 m    FOY
# 2    2085B603G029471            Flexometro 5 m x 3/4" Colores    FOY
# 3    2085B603G029496            Pala Cuadra C/Puño Y Plástica    FOY
# 4    2085B603G017377                  Adaptador En Y Plástico    FOY
# ..               ...                                      ...    ...
# 141  2085B604K035152              Llave de Chorro para Jardín  Urrea
# 142  2085B604J017920     Juego 8 Destornilladores Rojo 1000 V  Urrea
# 143  2085B604J017769          Llave Stillson Hierro 14"U/ x p  Urrea
# 144  2085B604J049795  Gato hidráulico de patín 3 ton compacto  Urrea
# 145  2085B604J017546            Matraca 3/8" Reversible Urrea  Urrea
#
#                  Category 3 Incluir? Codigo interno  \
# 0               Trapeadores       si         144182
# ...

# %%
dtf05 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_2.csv')
dtf05
# Out:
#       Código                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
dtf04 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wc-product-export-13-11-2023-1699876476102.csv")
dtf04
# Out:
#        ID    Tipo        SKU  \
# 0     410  simple     DDIS45
# 1     417  simple     DDIC45
# 2     419  simple     AMCS14
# 3     422  simple       U750
# 4     423  simple      DDIC7
# ..    ...     ...        ...
# 227  2010  simple  L26S50RJB
# 228  2012  simple       10CA
# 229  2014  simple       11CA
# 230  2016  simple     L21M36
# 231  2018  simple     CASO70
#
#                                                 Nombre  Publicado  \
# 0           Disco de diamante segmentado, 4-1/2" Urrea          1
# 1             Disco de diamante continuo, 4-1/2" Urrea          1
# 2    Disco abrasivo tipo 1 para metal 14" x 1/8" Urrea          1
# 3    Disco abrasivo tipo 27 para metal 4-1/2" x 1/8...          1
# 4                 Disco de diamante continuo, 7" Urrea          1
# ..                                                 ...        ...
# 227  Candado de combinación de disco, rojo, 50 mm Lock          1
# 228  Candado de combinación programable para maleta...          1
# ...

# %%
dtf05 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_2.csv')
dtf05.head()
# Out:
#     Código                                       Nombre corto  \
# 0    DA011               Abrillantador de llantas 1 Lt Surtek
# 1    DA010             Abrillantador de llantas 500 ml Surtek
# 2  L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3   140982                        Aceite multiusos 100 ml Foy
# 4   137212                 Aceitera flexible de 177 ml Surtek
#
#    Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                 1.0    47131828.0  Equipos y htas automo e hidrau
# 1                 1.0    47131828.0  Equipos y htas automo e hidrau
# 2                 1.0    31162409.0                      Cerrajeria
# 3                 1.0    15121520.0   Aceit, gras y eq p/manejo lub
# 4                10.0    27112908.0   Aceit, gras y eq p/manejo lub
#
#                 Categoría   Marca  Precio Sub distribuidor AGOSTO 23  \
# 0     Estética automotriz  Surtek                              120.0
# ...

# %%
df1 = pd.DataFrame( {'#a':[5,2], '#b':[3,1], '#c':[1,1], '#d':[2,1], '#e': [6,4]}  )

# %%
df1
# Out:
#    #a  #b  #c  #d  #e
# 0   5   3   1   2   6
# 1   2   1   1   1   4

# %%
df1.rename({'#a':'a', '#b':'b', '#c':'c', '#d':'d', '#e':'e'}, axis = 1)
# Out:
#    a  b  c  d  e
# 0  5  3  1  2  6
# 1  2  1  1  1  4

# %%
df1.rename({'#a':'a', '#b':'b', '#c':'c', '#d':'d', '#e':'e'}, axis = 'columns')
# Out:
#    a  b  c  d  e
# 0  5  3  1  2  6
# 1  2  1  1  1  4

# %%
df1.rename(lambda x: x[1:], axis = 1)
# Out:
#    a  b  c  d  e
# 0  5  3  1  2  6
# 1  2  1  1  1  4

# %%
import numpy as np

# %%
new_df = pd.DataFrame(np.random.normal(0,1,100).reshape(10,10), columns = ['#'+str(i)+'/col' for i in range(0,10)])

# %%
new_df
# Out:
#      #0/col    #1/col    #2/col    #3/col    #4/col    #5/col    #6/col  \
# 0 -0.940047 -0.666109  0.449790  0.648868 -0.522786 -1.236266  0.480058
# 1 -0.529570  0.441609 -1.850358  0.123119  1.589440 -0.242392 -2.172521
# 2  1.120331 -0.889829  0.798170 -0.034668  0.716448 -2.162626  2.975507
# 3 -0.443791 -0.307273 -2.039035 -1.128080 -0.028385  1.195260  0.181518
# 4 -0.714083 -0.861761 -0.173827 -0.516239  2.186985 -0.118160  0.355665
# 5 -0.662861 -0.968379  0.256588 -2.066632  0.944505  0.864159 -0.402628
# 6  0.379646  0.419560 -1.999823 -0.152437  1.282561 -0.408341 -0.693952
# 7 -2.275729  1.581509 -1.341548  0.290846  0.725449  1.629672  0.971710
# 8 -0.742090 -0.317930  0.268138  0.564237 -0.407862 -0.794543 -0.298387
# 9 -0.618347 -1.005580  0.807743  1.923992 -1.265826 -0.649162  0.692025
#
#      #7/col    #8/col    #9/col
# 0 -1.476333 -0.109345  0.470744
# 1  1.680152  2.038249  0.335355
# 2  1.998684 -0.072328  0.827916
# 3 -0.655920  0.519908  1.281892
# ...

# %%
def col_name(x):
  return x.replace('#','').replace('/','')

# %%
new_df.rename(col_name, axis = 'columns')
# Out:
#        0col      1col      2col      3col      4col      5col      6col  \
# 0 -0.940047 -0.666109  0.449790  0.648868 -0.522786 -1.236266  0.480058
# 1 -0.529570  0.441609 -1.850358  0.123119  1.589440 -0.242392 -2.172521
# 2  1.120331 -0.889829  0.798170 -0.034668  0.716448 -2.162626  2.975507
# 3 -0.443791 -0.307273 -2.039035 -1.128080 -0.028385  1.195260  0.181518
# 4 -0.714083 -0.861761 -0.173827 -0.516239  2.186985 -0.118160  0.355665
# 5 -0.662861 -0.968379  0.256588 -2.066632  0.944505  0.864159 -0.402628
# 6  0.379646  0.419560 -1.999823 -0.152437  1.282561 -0.408341 -0.693952
# 7 -2.275729  1.581509 -1.341548  0.290846  0.725449  1.629672  0.971710
# 8 -0.742090 -0.317930  0.268138  0.564237 -0.407862 -0.794543 -0.298387
# 9 -0.618347 -1.005580  0.807743  1.923992 -1.265826 -0.649162  0.692025
#
#        7col      8col      9col
# 0 -1.476333 -0.109345  0.470744
# 1  1.680152  2.038249  0.335355
# 2  1.998684 -0.072328  0.827916
# 3 -0.655920  0.519908  1.281892
# ...

# %%
new_df.rename(lambda x: x.replace('#','').replace('/',''), axis = 1)
# Out:
#        0col      1col      2col      3col      4col      5col      6col  \
# 0 -0.940047 -0.666109  0.449790  0.648868 -0.522786 -1.236266  0.480058
# 1 -0.529570  0.441609 -1.850358  0.123119  1.589440 -0.242392 -2.172521
# 2  1.120331 -0.889829  0.798170 -0.034668  0.716448 -2.162626  2.975507
# 3 -0.443791 -0.307273 -2.039035 -1.128080 -0.028385  1.195260  0.181518
# 4 -0.714083 -0.861761 -0.173827 -0.516239  2.186985 -0.118160  0.355665
# 5 -0.662861 -0.968379  0.256588 -2.066632  0.944505  0.864159 -0.402628
# 6  0.379646  0.419560 -1.999823 -0.152437  1.282561 -0.408341 -0.693952
# 7 -2.275729  1.581509 -1.341548  0.290846  0.725449  1.629672  0.971710
# 8 -0.742090 -0.317930  0.268138  0.564237 -0.407862 -0.794543 -0.298387
# 9 -0.618347 -1.005580  0.807743  1.923992 -1.265826 -0.649162  0.692025
#
#        7col      8col      9col
# 0 -1.476333 -0.109345  0.470744
# 1  1.680152  2.038249  0.335355
# 2  1.998684 -0.072328  0.827916
# 3 -0.655920  0.519908  1.281892
# ...

# %%
dtf04 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wc-product-export-13-11-2023-1699876476102.csv")
dtf04.head(1)
# Out:
#     ID    Tipo     SKU                                      Nombre  Publicado  \
# 0  410  simple  DDIS45  Disco de diamante segmentado, 4-1/2" Urrea          1
#
#    ¿Está destacado? Visibilidad en el catálogo  \
# 0                 0                    visible
#
#                                    Descripción corta  \
# 0  Para concreto, block, ladrillo, piedra y mater...
#
#                                          Descripción  \
# 0  Disco diamante uso industrial segmentado 4-1/2...
#
#    Día en que empieza el precio rebajado  ...  \
# 0                                    NaN  ...
#
#                                             Imágenes Límite de descargas  \
# 0  https://ferreterialafedecuicuilco.com/wp-conte...                 NaN
#
#    Días de caducidad de la descarga  Superior  Productos agrupados  \
# 0                               NaN       NaN                  NaN
#
#    Ventas dirigidas  Ventas cruzadas  URL externa  Texto del botón  Posición
# ...

# %%
data_col = dtf05[["Código", "Nombre corto", "Familia", "Marca", "Bullets (Puntos Clave ) Short Description", "Especificaciones técnicas", "URL Ficha Técnica (PDF)", ]]

# %%
data_col.head()
# Out:
#     Código                                       Nombre corto  \
# 0    DA011               Abrillantador de llantas 1 Lt Surtek
# 1    DA010             Abrillantador de llantas 500 ml Surtek
# 2  L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3   140982                        Aceite multiusos 100 ml Foy
# 4   137212                 Aceitera flexible de 177 ml Surtek
#
#                           Familia   Marca  \
# 0  Equipos y htas automo e hidrau  Surtek
# 1  Equipos y htas automo e hidrau  Surtek
# 2                      Cerrajeria    Lock
# 3   Aceit, gras y eq p/manejo lub     Foy
# 4   Aceit, gras y eq p/manejo lub  Surtek
#
#            Bullets (Puntos Clave ) Short Description  \
# 0  -Abrillantador Al 1 lt Surtek\n-Renueva, realz...
# 1  -Abrillantador All 500 ml Surtek\n-Renueva, re...
# 2  -Accesorio de seguridad para puerta cromo sati...
# 3  -Limpia, lubrica y previene la oxidación\n-Red...
# 4  -Aceiteras con bomba en una sola pieza\n-Recip...
#
# ...

# %%
data_col
# Out:
#       Código                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#                             Familia   Marca  \
# 0    Equipos y htas automo e hidrau  Surtek
# 1    Equipos y htas automo e hidrau  Surtek
# 2                        Cerrajeria    Lock
# ...

# %%
type(data_col)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_colums = ["Código", "Nombre corto", "Familia", "Marca", "Bullets (Puntos Clave ) Short Description", "Especificaciones técnicas", "URL Ficha Técnica (PDF)"]
subset = dtf05[desired_colums]
subset.head()
# Out:
#     Código                                       Nombre corto  \
# 0    DA011               Abrillantador de llantas 1 Lt Surtek
# 1    DA010             Abrillantador de llantas 500 ml Surtek
# 2  L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3   140982                        Aceite multiusos 100 ml Foy
# 4   137212                 Aceitera flexible de 177 ml Surtek
#
#                           Familia   Marca  \
# 0  Equipos y htas automo e hidrau  Surtek
# 1  Equipos y htas automo e hidrau  Surtek
# 2                      Cerrajeria    Lock
# 3   Aceit, gras y eq p/manejo lub     Foy
# 4   Aceit, gras y eq p/manejo lub  Surtek
#
#            Bullets (Puntos Clave ) Short Description  \
# 0  -Abrillantador Al 1 lt Surtek\n-Renueva, realz...
# 1  -Abrillantador All 500 ml Surtek\n-Renueva, re...
# 2  -Accesorio de seguridad para puerta cromo sati...
# 3  -Limpia, lubrica y previene la oxidación\n-Red...
# 4  -Aceiteras con bomba en una sola pieza\n-Recip...
#
# ...

# %%
desired_colums = ["Código", "Nombre corto", "Familia", "Marca", "Bullets (Puntos Clave ) Short Description", "Especificaciones técnicas", "URL Ficha Técnica (PDF)"]
desired_colums
# Out:
# ['Código',
#  'Nombre corto',
#  'Familia',
#  'Marca',
#  'Bullets (Puntos Clave ) Short Description',
#  'Especificaciones técnicas',
#  'URL Ficha Técnica (PDF)']

# %%
all_columns_list = dtf05.columns.values.tolist()
all_columns_list
# Out:
# ['Código',
#  'Nombre corto',
#  'Múltiplo de venta ',
#  'Anexo 20 SAT',
#  'Familia',
#  'Categoría',
#  'Marca',
#  'Precio Sub distribuidor AGOSTO 23',
#  'EAN o UPC',
#  'Bullets (Puntos Clave ) Short Description',
#  'Especificaciones técnicas',
#  'Contenido (Incluye / Accesoriso)',
#  'Nueva foto HD',
#  'Link Video',
#  'URL Ficha Técnica (JPG)',
#  'URL Ficha Técnica (PDF)',
#  'Contenido de juego PDF',
#  'Manual de uso',
#  'Garantía',
#  'Palabras clave',
#  'Alto paquete cm ',
#  'Largo (Paquete) cm ',
#  'Fondo (Paquete) cm',
#  'Peso (paquete) Kg']

# %%
all_columns_list = dtf04.columns.values.tolist()
all_columns_list
# Out:
# ['ID',
#  'Tipo',
#  'SKU',
#  'Nombre',
#  'Publicado',
#  '¿Está destacado?',
#  'Visibilidad en el catálogo',
#  'Descripción corta',
#  'Descripción',
#  'Día en que empieza el precio rebajado',
#  'Día en que termina el precio rebajado',
#  'Estado del impuesto',
#  'Clase de impuesto',
#  '¿Existencias?',
#  'Inventario',
#  'Cantidad de bajo inventario',
#  '¿Permitir reservas de productos agotados?',
#  '¿Vendido individualmente?',
#  'Peso (kg)',
#  'Longitud (cm)',
#  'Anchura (cm)',
#  'Altura (cm)',
#  '¿Permitir valoraciones de clientes?',
#  'Nota de compra',
#  'Precio rebajado',
#  'Precio normal',
#  'Categorías',
#  'Etiquetas',
#  'Clase de envío',
#  'Imágenes',
#  'Límite de descargas',
#  'Días de caducidad de la descarga',
#  'Superior',
#  'Productos agrupados',
#  'Ventas dirigidas',
#  'Ventas cruzadas',
#  'URL externa',
#  'Texto del botón',
#  'Posición']

# %%
sublist = [x for x in all_columns_list if x not in desired_colums]
sublist
# Out:
# ['ID',
#  'Tipo',
#  'SKU',
#  'Nombre',
#  'Publicado',
#  '¿Está destacado?',
#  'Visibilidad en el catálogo',
#  'Descripción corta',
#  'Descripción',
#  'Día en que empieza el precio rebajado',
#  'Día en que termina el precio rebajado',
#  'Estado del impuesto',
#  'Clase de impuesto',
#  '¿Existencias?',
#  'Inventario',
#  'Cantidad de bajo inventario',
#  '¿Permitir reservas de productos agotados?',
#  '¿Vendido individualmente?',
#  'Peso (kg)',
#  'Longitud (cm)',
#  'Anchura (cm)',
#  'Altura (cm)',
#  '¿Permitir valoraciones de clientes?',
#  'Nota de compra',
#  'Precio rebajado',
#  'Precio normal',
#  'Categorías',
#  'Etiquetas',
#  'Clase de envío',
#  'Imágenes',
#  'Límite de descargas',
#  'Días de caducidad de la descarga',
#  'Superior',
#  'Productos agrupados',
#  'Ventas dirigidas',
#  'Ventas cruzadas',
#  'URL externa',
#  'Texto del botón',
#  'Posición']

# %%
dtf05 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_2.csv')
dtf05
# Out:
#       Código                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
dtf05.rename({'Código':'SKU'}, axis = 'columns')
# Out:
#          SKU                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
dtf05.rename({'Nombre Corto':'Nombre'}, axis = 'columns')
# Out:
#       Código                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
dtf05
# Out:
#       Código                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
dtf05.rename({'Código':'SKU', 'Nombre corto':'Nombre', 'Bullets (Puntos Clave ) Short Description':'Descripción corta'}, axis = 'columns')
# Out:
#          SKU                                             Nombre  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
dtf05.rename({'Código':'SKU', 'Nombre corto':'Nombre', 'Bullets (Puntos Clave ) Short Description':'Descripción corta', 'Especificaciones técnicas':'Descripción', 'Nueva foto HD':'Imágenes'}, axis = 'columns')
# Out:
#          SKU                                             Nombre  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
dtf05.rename({'Código':'SKU', 'Nombre corto':'Nombre', 'Bullets (Puntos Clave ) Short Description':'Descripción corta', 'Especificaciones técnicas':'Descripción', 'Nueva foto HD':'Imágenes'}, axis = 'columns')
# Out:
#          SKU                                             Nombre  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
dtf05.to_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_3.csv', index=False)

# %%
dtf05.to_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_3.csv', index=False)

# %%
dtf06 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_3.csv')
dtf06
# Out:
#       Código                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#      Múltiplo de venta   Anexo 20 SAT                         Familia  \
# 0                   1.0    47131828.0  Equipos y htas automo e hidrau
# ...

# %%
desired_colums = ["Código", "Nombre corto", "Bullets (Puntos Clave ) Short Description", "Especificaciones técnicas", "Nueva foto HD"]
subset = dtf05[desired_colums]
subset.head()
# Out:
#     Código                                       Nombre corto  \
# 0    DA011               Abrillantador de llantas 1 Lt Surtek
# 1    DA010             Abrillantador de llantas 500 ml Surtek
# 2  L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3   140982                        Aceite multiusos 100 ml Foy
# 4   137212                 Aceitera flexible de 177 ml Surtek
#
#            Bullets (Puntos Clave ) Short Description  \
# 0  -Abrillantador Al 1 lt Surtek\n-Renueva, realz...
# 1  -Abrillantador All 500 ml Surtek\n-Renueva, re...
# 2  -Accesorio de seguridad para puerta cromo sati...
# 3  -Limpia, lubrica y previene la oxidación\n-Red...
# 4  -Aceiteras con bomba en una sola pieza\n-Recip...
#
#                            Especificaciones técnicas  \
# 0                                    -Contenido: 1 L
# 1                                 -Contenido: 500 Ml
# 2  -Acabado: Cromo Satinado\n-Largo Contra Mm: 24...
# ...

# %%
subset.to_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_4.csv', index=False)

# %%
dtf06 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_4.csv')
dtf06
# Out:
#       Código                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#              Bullets (Puntos Clave ) Short Description  \
# 0    -Abrillantador Al 1 lt Surtek\n-Renueva, realz...
# 1    -Abrillantador All 500 ml Surtek\n-Renueva, re...
# ...

# %%
dtf06.rename({'Código':'SKU', 'Nombre corto':'Nombre', 'Bullets (Puntos Clave ) Short Description':'Descripción corta', 'Especificaciones técnicas':'Descripción', 'Nueva foto HD':'Imágenes'}, axis = 'columns')
# Out:
#          SKU                                             Nombre  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#                                      Descripción corta  \
# 0    -Abrillantador Al 1 lt Surtek\n-Renueva, realz...
# 1    -Abrillantador All 500 ml Surtek\n-Renueva, re...
# ...

# %%
dtf_modificado = dtf06.rename(columns={'Código':'SKU', 'Nombre corto':'Nombre', 'Bullets (Puntos Clave ) Short Description':'Descripción corta', 'Especificaciones técnicas':'Descripción', 'Nueva foto HD':'Imágenes'})

# %%
dtf_modificado
# Out:
#          SKU                                             Nombre  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#                                      Descripción corta  \
# 0    -Abrillantador Al 1 lt Surtek\n-Renueva, realz...
# 1    -Abrillantador All 500 ml Surtek\n-Renueva, re...
# ...

# %%
dtf06.to_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_4.csv', index=False)

# %%
dtf06
# Out:
#       Código                                       Nombre corto  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#              Bullets (Puntos Clave ) Short Description  \
# 0    -Abrillantador Al 1 lt Surtek\n-Renueva, realz...
# 1    -Abrillantador All 500 ml Surtek\n-Renueva, re...
# ...

# %%
desired_colums = ["Código", "Nombre corto", "Familia", "Marca", "Bullets (Puntos Clave ) Short Description", "Especificaciones técnicas", "URL Ficha Técnica (PDF)", "Alto paquete cm ", "Largo (Paquete) cm ", "Fondo (Paquete) cm", "Peso (paquete) Kg"]
New_dtf1 = dtf05[desired_colums]
New_dtf1.head()
# Out:
#     Código                                       Nombre corto  \
# 0    DA011               Abrillantador de llantas 1 Lt Surtek
# 1    DA010             Abrillantador de llantas 500 ml Surtek
# 2  L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3   140982                        Aceite multiusos 100 ml Foy
# 4   137212                 Aceitera flexible de 177 ml Surtek
#
#                           Familia   Marca  \
# 0  Equipos y htas automo e hidrau  Surtek
# 1  Equipos y htas automo e hidrau  Surtek
# 2                      Cerrajeria    Lock
# 3   Aceit, gras y eq p/manejo lub     Foy
# 4   Aceit, gras y eq p/manejo lub  Surtek
#
#            Bullets (Puntos Clave ) Short Description  \
# 0  -Abrillantador Al 1 lt Surtek\n-Renueva, realz...
# 1  -Abrillantador All 500 ml Surtek\n-Renueva, re...
# 2  -Accesorio de seguridad para puerta cromo sati...
# 3  -Limpia, lubrica y previene la oxidación\n-Red...
# 4  -Aceiteras con bomba en una sola pieza\n-Recip...
#
# ...

# %%
all_columns_list = New_dtf1.columns.values.tolist()
all_columns_list
# Out:
# ['Código',
#  'Nombre corto',
#  'Familia',
#  'Marca',
#  'Bullets (Puntos Clave ) Short Description',
#  'Especificaciones técnicas',
#  'URL Ficha Técnica (PDF)',
#  'Alto paquete cm ',
#  'Largo (Paquete) cm ',
#  'Fondo (Paquete) cm',
#  'Peso (paquete) Kg']

# %%
New_dtf1.rename({'Código':'SKU', 'Nombre corto':'Nombre', 'Bullets (Puntos Clave ) Short Description':'Descripción corta', 'Especificaciones técnicas':'Descripción', 'Nueva foto HD':'Imágenes', 'Alto paquete cm ': 'Altura (cm)', 'Largo (Paquete) cm ':'Longitud (cm)', 'Fondo (Paquete) cm':'Anchura (cm)', 'Peso (paquete) Kg':'Peso (kg)'}, axis = 'columns')
# Out:
#          SKU                                             Nombre  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#                             Familia   Marca  \
# 0    Equipos y htas automo e hidrau  Surtek
# 1    Equipos y htas automo e hidrau  Surtek
# 2                        Cerrajeria    Lock
# ...

# %%
Adtf_modificado = New_dtf1.rename(columns={'Código':'SKU', 'Nombre corto':'Nombre', 'Bullets (Puntos Clave ) Short Description':'Descripción corta', 'Especificaciones técnicas':'Descripción', 'Nueva foto HD':'Imágenes', 'Alto paquete cm ': 'Altura (cm)', 'Largo (Paquete) cm ':'Longitud (cm)', 'Fondo (Paquete) cm':'Anchura (cm)', 'Peso (paquete) Kg':'Peso (kg)'})

# %%
Adtf_modificado
# Out:
#          SKU                                             Nombre  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#                             Familia   Marca  \
# 0    Equipos y htas automo e hidrau  Surtek
# 1    Equipos y htas automo e hidrau  Surtek
# 2                        Cerrajeria    Lock
# ...

# %%
Adtf_modificado.to_csv('/content/drive/MyDrive/Colab Notebooks/PLANTILLA_5A.csv', index=False)

# %%
all_columns_list = Adtf_modificado.columns.values.tolist()
all_columns_list
# Out:
# ['SKU',
#  'Nombre',
#  'Familia',
#  'Marca',
#  'Descripción corta',
#  'Descripción',
#  'URL Ficha Técnica (PDF)',
#  'Altura (cm)',
#  'Longitud (cm)',
#  'Anchura (cm)',
#  'Peso (kg)']

# %%
dtf04 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wc-product-export-13-11-2023-1699876476102.csv")
dtf04.head(1)
# Out:
#     ID    Tipo     SKU                                      Nombre  Publicado  \
# 0  410  simple  DDIS45  Disco de diamante segmentado, 4-1/2" Urrea          1
#
#    ¿Está destacado? Visibilidad en el catálogo  \
# 0                 0                    visible
#
#                                    Descripción corta  \
# 0  Para concreto, block, ladrillo, piedra y mater...
#
#                                          Descripción  \
# 0  Disco diamante uso industrial segmentado 4-1/2...
#
#    Día en que empieza el precio rebajado  ...  \
# 0                                    NaN  ...
#
#                                             Imágenes Límite de descargas  \
# 0  https://ferreterialafedecuicuilco.com/wp-conte...                 NaN
#
#    Días de caducidad de la descarga  Superior  Productos agrupados  \
# 0                               NaN       NaN                  NaN
#
#    Ventas dirigidas  Ventas cruzadas  URL externa  Texto del botón  Posición
# ...

# %%
Adtf_modificado['Productos agrupados'] = dtf04['Productos agrupados']

# %%
all_columns_list = dtf04.columns.values.tolist()
all_columns_list
# Out:
# ['ID',
#  'Tipo',
#  'SKU',
#  'Nombre',
#  'Publicado',
#  '¿Está destacado?',
#  'Visibilidad en el catálogo',
#  'Descripción corta',
#  'Descripción',
#  'Día en que empieza el precio rebajado',
#  'Día en que termina el precio rebajado',
#  'Estado del impuesto',
#  'Clase de impuesto',
#  '¿Existencias?',
#  'Inventario',
#  'Cantidad de bajo inventario',
#  '¿Permitir reservas de productos agotados?',
#  '¿Vendido individualmente?',
#  'Peso (kg)',
#  'Longitud (cm)',
#  'Anchura (cm)',
#  'Altura (cm)',
#  '¿Permitir valoraciones de clientes?',
#  'Nota de compra',
#  'Precio rebajado',
#  'Precio normal',
#  'Categorías',
#  'Etiquetas',
#  'Clase de envío',
#  'Imágenes',
#  'Límite de descargas',
#  'Días de caducidad de la descarga',
#  'Superior',
#  'Productos agrupados',
#  'Ventas dirigidas',
#  'Ventas cruzadas',
#  'URL externa',
#  'Texto del botón',
#  'Posición']

# %%
Adtf_modificado
# Out:
#          SKU                                             Nombre  \
# 0      DA011               Abrillantador de llantas 1 Lt Surtek
# 1      DA010             Abrillantador de llantas 500 ml Surtek
# 2    L044CSB  Accesorio de seguridad para puerta acabado níq...
# 3     140982                        Aceite multiusos 100 ml Foy
# 4     137212                 Aceitera flexible de 177 ml Surtek
# ..       ...                                                ...
# 901    VR381                  Varilla roscada 3/8" x 1 m Surtek
# 902   VR5161                 Varilla roscada 5/16" x 1 m Surtek
# 903   123194     Volteador de aluminio de una sola pieza Surtek
# 904     ZP7M  Zapa-pico con mango de madera de 36", 7 lb Surtek
# 905    ZP5MF  Zapa-pico con mango de fibra de vidrio de 36",...
#
#                             Familia   Marca  \
# 0    Equipos y htas automo e hidrau  Surtek
# 1    Equipos y htas automo e hidrau  Surtek
# 2                        Cerrajeria    Lock
# ...

# %%
all_columns_list = Adtf_modificado.columns.values.tolist()
all_columns_list
# Out:
# ['SKU',
#  'Nombre',
#  'Familia',
#  'Marca',
#  'Descripción corta',
#  'Descripción',
#  'URL Ficha Técnica (PDF)',
#  'Altura (cm)',
#  'Longitud (cm)',
#  'Anchura (cm)',
#  'Peso (kg)',
#  'Productos agrupados']

# %%
dtf04.head()
# Out:
#     ID    Tipo     SKU                                             Nombre  \
# 0  410  simple  DDIS45         Disco de diamante segmentado, 4-1/2" Urrea
# 1  417  simple  DDIC45           Disco de diamante continuo, 4-1/2" Urrea
# 2  419  simple  AMCS14  Disco abrasivo tipo 1 para metal 14" x 1/8" Urrea
# 3  422  simple    U750  Disco abrasivo tipo 27 para metal 4-1/2" x 1/8...
# 4  423  simple   DDIC7               Disco de diamante continuo, 7" Urrea
#
#    Publicado  ¿Está destacado? Visibilidad en el catálogo  \
# 0          1                 0                    visible
# 1          1                 0                    visible
# 2          1                 0                    visible
# 3          1                 0                    visible
# 4          1                 0                    visible
#
#                                    Descripción corta  \
# 0  Para concreto, block, ladrillo, piedra y mater...
# 1  cortes terminados finos sin desportilladuras,\...
# ...

# %%
desired_colums = ['Tipo','SKU','Nombre','Publicado','¿Está destacado?','Visibilidad en el catálogo','Descripción corta','Descripción','Día en que empieza el precio rebajado','Día en que termina el precio rebajado','Estado del impuesto','Clase de impuesto','¿Existencias?','Inventario','Cantidad de bajo inventario','¿Permitir reservas de productos agotados?','¿Vendido individualmente?','Peso (kg)','Longitud (cm)','Anchura (cm)','Altura (cm)','¿Permitir valoraciones de clientes?','Nota de compra','Precio rebajado','Precio normal','Etiquetas','Clase de envío','Imágenes','Límite de descargas','Días de caducidad de la descarga','Superior','Productos agrupados','Ventas dirigidas','Ventas cruzadas','URL externa','Texto del botón','Posición']
New_xot = dtf04[desired_colums]
New_xot.head()
# Out:
#      Tipo     SKU                                             Nombre  \
# 0  simple  DDIS45         Disco de diamante segmentado, 4-1/2" Urrea
# 1  simple  DDIC45           Disco de diamante continuo, 4-1/2" Urrea
# 2  simple  AMCS14  Disco abrasivo tipo 1 para metal 14" x 1/8" Urrea
# 3  simple    U750  Disco abrasivo tipo 27 para metal 4-1/2" x 1/8...
# 4  simple   DDIC7               Disco de diamante continuo, 7" Urrea
#
#    Publicado  ¿Está destacado? Visibilidad en el catálogo  \
# 0          1                 0                    visible
# 1          1                 0                    visible
# 2          1                 0                    visible
# 3          1                 0                    visible
# 4          1                 0                    visible
#
#                                    Descripción corta  \
# 0  Para concreto, block, ladrillo, piedra y mater...
# 1  cortes terminados finos sin desportilladuras,\...
# ...

# %%
dtf40 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/KKK.csv")
dtf40.head(2)
# Out:
#      Tipo     SkU                                             Nombre  \
# 0  simple  100166  Llave combinada pulido espejo en pulgadas 12 p...
# 1  simple  100166  Dado de impacto largo cuadro de 1", 6 puntas, ...
#
#    Publicado  ¿Está destacado? Visibilidad en el catálogo  \
# 0          1                 0                    visible
# 1          1                 0                    visible
#
#                                    Descripción corta  \
# 0  Pulido espejo  Fabricadas en acero cromo vanad...
# 1  Dado de impacto cuadro 1" largo 6 puntas medid...
#
#                                          Descripción  \
# 0               Longitud: 168 Mm -Sae O Métrico: Sae
# 1  Diámetro Exterior De Cuadro: 2""  Longitud: 3 ...
#
#    Día en que empieza el precio rebajado  \
# 0                                    NaN
# 1                                    NaN
#
#    Día en que termina el precio rebajado  ...  \
# 0                                    NaN  ...
# ...

# %%
all_columns_list = dtf40.columns.values.tolist()
all_columns_list
# Out:
# ['Tipo',
#  'SkU',
#  'Nombre',
#  'Publicado',
#  '¿Está destacado?',
#  'Visibilidad en el catálogo',
#  'Descripción corta',
#  'Descripción',
#  'Día en que empieza el precio rebajado',
#  'Día en que termina el precio rebajado',
#  'Estado del impuesto',
#  'Clase de impuesto',
#  '¿Existencias?',
#  'Inventario',
#  'Cantidad de bajo inventario',
#  '¿Permitir reservas de productos agotados?',
#  '¿Vendido individualmente?',
#  'Peso (kg)',
#  'Anchura (cm)',
#  'Nota de compra',
#  'Precio rebajado',
#  'Categorias',
#  'Etiquetas',
#  'Clase de envío',
#  'Imágenes',
#  'Límite de descargas',
#  'Días de caducidad de la descarga',
#  'Superior',
#  'Productos agrupados',
#  'Ventas dirigidas',
#  'Ventas cruzadas',
#  'URL externa',
#  'Texto del botón',
#  'Posición']
