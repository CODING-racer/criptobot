# %% [markdown]
# <a href="https://colab.research.google.com/github/CODING-racer/criptobot/blob/main/Matplotlib_Varios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from sklearn import svm
import numpy as np

# %%
X_data = np.random.random(50) * 100
Y_data = np.random.random(50) * 100

# %%
print(Y_data)
# Out:
# [89.32125227 39.87927326 93.07301675 34.03194864 72.25967322 46.27391452
#  91.50792517 91.01838695 65.48991651  4.19148215 68.00058994 38.31855264
#  22.54885713 33.14408111 97.65164413 55.12424422 38.46151554  2.95872049
#  83.15294388 96.11087143  4.76448328 20.63324402 77.83790041 40.3070663
#  51.30500891 23.2434256  83.26405353 29.02984665 38.88671433 35.46749855
#  84.52237656 28.42040256 51.042746   28.82501171 59.78357469 13.61765065
#  36.40831175 10.91793151 72.76159291 54.63386376 50.00185129 65.29253955
#   8.2095341  77.86767122 59.68566514  6.91205345 67.23196914 49.49549035
#  78.84685024  7.24277468]

# %%
plt.rcParams["figure.figsize"] = [10,6]

# %%
plt.scatter(X_data, Y_data, c= "black", s = 50, marker= "*")  # color, tamaño y figura
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
X_data = np.random.random(50) * 100
Y_data = np.random.random(50) * 100

# %%
plt.rcParams["figure.figsize"] = [10,6]

# %%
years = [2006 + x for x in range (16)]
weights = [80,83,84,85,86,82,81,79,83,88,82,82,83,81,80,79]

plt.plot(years, weights, c= "g" , lw=3,
        linestyle = "-")                # Se puede definir el color con la inicial
plt.show()                               # y el ancho de linea (lw),asi como el linestyle .
                                         # Tambien al mismo tiempo color y ninestyle ("g--")

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
x = ["C++", "Swift", "Python", "Java", "Go"]
y = [20, 50, 140, 5, 45]

# %%
plt.rcParams["figure.figsize"] = [10,6]

# %%
plt.plot(x, y, "b-", lw=3)
plt.show()

# %%
plt.bar(x,y, color="g", width=1, edgecolor= "black", lw=1)
plt.show()                              # lw solo cuando son puntos o lineas , no barras

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
ages = np.random.normal(20, 7.5, 1000)    # Media , desviación estandar y muestra
print(ages)
# Out:
# [19.57303173 15.30594929 20.70217213 19.81656727 12.22085986  6.93852108
#  10.32415045 23.87656869 25.61156239 20.21702699 23.07596378 13.08977659
#  20.52735775 13.7960102  13.45076911 27.76905894  8.26618839 26.22428209
#  30.50911874 10.38523739 20.74716821 23.84686567 15.81971048 28.26734158
#  21.92496218 14.78424978 20.14580631 12.4690873  11.30302806 26.13560281
#  15.30833098 27.23198881 19.84067904 25.48184949 24.51576778 20.99045927
#  36.35953757 29.54221391 20.07582699 23.17684978 22.64942469 13.92544671
#  28.50882858  9.38536217 14.64962206 24.73208356 19.62688371 10.78729572
#  11.8851942  23.34874713 20.54863419 13.58814481 22.1382543  28.47755369
#  14.23322168 20.77286346 11.00276256 31.35273504 22.45085701 17.61480088
#   6.70120917 16.94416196  4.84602494 16.87308735  6.71438314 22.67398352
#  32.79901878 16.77018525 17.00748856 17.27628952 23.38785975 25.07592685
#  23.30777805 22.07030442 21.89337102 32.4022359  17.91858038 20.11639913
# ...

# %%
plt.rcParams["figure.figsize"] = [11,7]

# %%
plt.hist(ages, bins = 20)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ages = np.random.normal(20, 7.5, 1000)    # Media , desviación estandar y muestra
print(ages)
# Out:
# [10.42025983 21.99172088 26.19759616 27.79823176 16.16655591 -0.37951105
#  14.21389799 22.17596582 22.32222258  0.90934261 19.68394647 19.20160116
#  11.37323355 24.68143133 22.20087031 17.25069846 23.5740288  10.26907314
#  22.45996042 24.71943994 -0.59702719 12.32218027 32.52222341 15.03146547
#  30.97124704 35.94369039 32.82089552 26.05347886 24.05452361 17.07138002
#  16.13850563 29.86639947 22.77983839 30.15401247 26.06985659 18.50926283
#  19.52840865 26.27361925 20.17142619 20.73344589  6.32632269 26.42949506
#   9.27940864 19.84224125 18.64398119 15.20076802 22.62381195 23.26153883
#  22.19824341 22.72920066 24.15069509 32.72674034 12.98774986 18.0873922
#  21.05717748 22.66422795 21.41669785 14.33576495 30.77302058  7.83990885
#  26.15619058 20.25415288 13.0906992  11.66546268 22.73943086 21.78667521
#  34.53615853 18.23350318 23.13174899 19.41588707 28.77470468 21.68141961
#  14.93591428 20.9856319  15.54559679 25.23686127 22.8316519  18.3400627
# ...

# %%
plt.rcParams["figure.figsize"] = [10,6]

# %%
plt.hist(ages, bins = 20, cumulative= True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
plt.rcParams["figure.figsize"] = [11,7]

# %%
langs = ["Python", " C++", "Java", "Swift", "Go"]
votes = [50, 24, 14, 6, 17]

# %%
plt.pie(votes, labels=langs)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
langs = ["Python", " C++", "Java", "Swift", "Go"]
votes = [50, 24, 14, 6, 17]
explodes = [0, 0, 0, 0.2, 0]

# %%
plt.rcParams["figure.figsize"] = [11,7]

# %%
plt.pie(votes, labels=langs, explode=explodes)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
langs = ["Python", " C++", "Java", "Swift", "Go"]
votes = [50, 24, 14, 6, 17]
explodes = [0.3, 0, 0, 0, 0]

# %%
plt.rcParams["figure.figsize"] = [11,7]

# %%
plt.pie(votes, labels=langs, explode=explodes)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
langs = ["Python", " C++", "Java", "Swift", "Go"]
votes = [50, 24, 14, 6, 17]
explodes = [0.3, 0, 0, 0, 0]

# %%
plt.rcParams["figure.figsize"] = [11,7]  style.use("dark_background")
# Out:
#   Input In [16]
#     plt.rcParams["figure.figsize"] = [11,7]  style.use("dark_background")
#                                              ^
# SyntaxError: invalid syntax

# %%
plt.pie(votes, labels=langs, explode=explodes,autopct= "%.2f%%")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
langs = ["Python", " C++", "Java", "Swift", "Go"]
votes = [50, 24, 14, 6, 17]
explodes = [0.3, 0, 0, 0, 0]

# %%
plt.rcParams["figure.figsize"] = [10,6]
style.use("dark_background")

# %%
plt.pie(votes, labels=langs, explode=explodes,autopct= "%.2f%%", pctdistance= 1.8)
# Out:
# ([<matplotlib.patches.Wedge at 0x1aad0d64310>,
# ...
#  [Text(0.21705124069647674, 1.38307221753317, 'Python'),
#   Text(-1.026379583540609, -0.39565761775935265, ' C++'),
#   Text(-0.13971956997060672, -1.0910904828506338, 'Java'),
#   Text(0.4672301561865249, -0.9958393350083716, 'Swift'),
#   Text(0.9751122708702095, -0.509073726682436, 'Go')],
#  [Text(0.32557686104471506, 2.074608326299755, '45.05%'),
#   Text(-1.6795302276119057, -0.6474397381516679, '21.62%'),
#   Text(-0.2286320235882655, -1.7854207901192187, '12.61%'),
#   Text(0.7645584373961316, -1.6295552754682443, '5.41%'),
#   Text(1.595638261423979, -0.8330297345712588, '15.32%')])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
heights = np.random.normal(172, 8, 300)

# %%
print(heights)
# Out:
# [174.29148062 174.40037365 172.00607901 165.97778662 162.59207463
#  173.20743182 175.58478207 164.09546588 181.909583   182.94406646
#  163.79979976 173.87812274 172.57971278 177.66495576 178.17369521
#  168.55996009 190.45189826 179.89017323 184.12737007 168.70787016
#  164.46099267 186.29185079 176.97785662 179.49823913 155.1268603
#  163.4423568  178.1294435  162.43043161 168.83939202 177.72599503
#  178.62060215 170.6812046  172.00350961 167.4115377  177.99377436
#  179.61954128 180.07505107 163.8865807  176.07426756 175.54070485
#  179.22004836 170.59395404 175.98429011 167.0876942  171.04380117
#  170.68029204 160.13603665 163.27444042 163.27084007 171.68542483
#  171.53768661 175.1101843  185.10113788 165.21404746 184.88513335
#  162.96089166 164.69431543 173.38048949 182.91835676 158.24728968
#  162.85213931 170.31689344 166.58417425 154.84114353 173.0010445
#  159.41858461 167.60240998 176.11877843 164.2223414  173.19800529
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
heights = np.random.normal(172, 8, 300)

# %%
plt.rcParams["figure.figsize"] = [11,7]
style.use("dark_background")

# %%
plt.boxplot(heights)
plt.grid()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [11,7]
style.use("dark_background")

# %%
first = np.linspace(0, 10, 25)
second = np.linspace(10, 200, 25 )
third = np.linspace(200, 210, 25)
fourth = np.linspace(210, 230, 25)

data = np.concatenate((first, second, third, fourth))

plt.boxplot(data)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
plt.rcParams["figure.figsize"] = [11,7]

# %%
years = [2014, 2015, 2016, 2017,
        2018, 2019, 2020, 2021]

income = [55, 56, 63, 61,
         72, 72, 73, 75]

income_ticks = list(range(50,81,2))

plt.plot(years, income)
plt.title("Income of John (in USD)", fontsize = 25, fontname = "FreeSerif")
plt.xlabel("Year")
plt.ylabel("Yearly Income in USD")
plt.yticks(income_ticks, [f"${x}x" for x in income_ticks])
plt.show()
# Out:
# findfont: Font family ['FreeSerif'] not found. Falling back to DejaVu Sans.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
plt.rcParams["figure.figsize"] = [11,7]

# %%
plt.rcParams["figure.figsize"] = [11,7]
style.use("dark_background")

# %%
stock_a = [100, 102, 99, 101, 101, 100, 102]
stock_b = [90, 95, 102, 104, 105, 103, 109]
stock_c = [110, 115, 100, 105, 100, 98, 95]

plt.plot(stock_a, label="Company1")
plt.plot(stock_b, label="Company2")
plt.plot(stock_c, label="Company3")

plt.legend(loc="upper center")
plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = [11,7]

# %%
votes = [10, 2, 5, 16, 22]
people = ["A", "B","C", "D","E"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
#style.use("ggplot")
plt.rcParams["figure.figsize"] = [11,7]
style.use("dark_background")

# %%
votes = [10, 2, 5, 16, 22]
people = ["A", "B","C", "D","E"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use("dark_background")
plt.rcParams["figure.figsize"] = [11,7]

# %%
votes = [10, 2, 5, 16, 22]
people = ["A", "B","C", "D","E"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
plt.rcParams["figure.figsize"] = [11, 7]           # Tamaño de gráfica
style.use("dark_background")                      # Fondo oscuro

# %%
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

plt.figure(1)
plt.scatter(x1, y1)

plt.figure(2)
plt.plot(x2, y2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
plt.rcParams["figure.figsize"] = [11,7]
style.use("dark_background")

# %%
x = np.arange(100)

fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(x, np.sin(x))
axs[0, 0].set_title("Sine Wave")

axs[0, 1].plot(x, np.cos(x))
axs[0, 1].set_title("Cosine Wave")

axs[1, 0].plot(x, np.random.random(100))
axs[1, 0].set_title("Random Function")

axs[1, 1].plot(x, np.log(x))
axs[1, 1].set_title("Log Function")

fig.suptitle("Four Plots")

plt.show()
# Out:
# C:\Users\pacos\AppData\Local\Temp\ipykernel_12996\1062050840.py:14: RuntimeWarning: divide by zero encountered in log
#   axs[1, 1].plot(x, np.log(x))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

plt.rcParams["figure.figsize"] = [11,7]

# %%
ax = plt.axes(projection="3d")

x = np.random.random(100)
y = np.random.random(100)
z = np.random.random(100)

ax.scatter(x, y, z)
ax.set_title("3D Plot")
ax.set_xlabel("test")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
plt.rcParams["figure.figsize"] = [11,7]

# %%
ax = plt.axes(projection="3d")

x = np.arange(0, 50, 0.1)
y = np.arange(0, 50, 0.1)
z = np.cos(x + y)

ax.scatter(x, y, z)
ax.set_title("3D Plot")
ax.set_xlabel("test")

plt.show()

# %%
import matplotlib.pyplot as plt                             # No tiene mucho caso
import numpy as np
from matplotlib import style
plt.rcParams["figure.figsize"] = [9,5]

# %%
labels = ["A","B","C","D"]
values = [10,15,13,17]
colors = ["blue","green","red","purple"]

plt.bar(labels,values,color=colors)
plt.show()
