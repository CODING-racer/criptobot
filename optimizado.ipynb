# %%
import pandas as pd
import yfinance as yf

# %%
ticker = "BTC-USD"
BTC = yf.download(ticker, start="2024-01-01", end="2024-08-09")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
BTC.shape
# Out:
# (221, 6)

# %%
BTC
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# ...                  ...           ...           ...           ...
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
# 2024-08-06  53991.347656  57059.917969  53973.273438  56034.316406
# 2024-08-07  56040.632812  57726.882812  54620.507812  55027.460938
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
#
#                Adj Close        Volume
# Date
# 2024-01-01  44167.332031   18426978443
# 2024-01-02  44957.968750   39335274536
# ...

# %%
tickers = "ETH-USD", "XRP-USD", "LTC-USB", "BCH-USD", "ADA-USD", "DOT-USD", "BNB-USD", "DOGE-USD", "SOL-USD", "XLM-USD", "USDT-USD", "UNI-USD", "LINK-USD", "AVAX-USD" 
ETH = yf.download(ticker, start="2024-01-01", end="2024-08-09")
XRP = yf.download(ticker, start="2024-01-01", end="2024-08-09")
LTC = yf.download(ticker, start="2024-01-01", end="2024-08-09")
BCH = yf.download(ticker, start="2024-01-01", end="2024-08-09")
ADA = yf.download(ticker, start="2024-01-01", end="2024-08-09")
DOT = yf.download(ticker, start="2024-01-01", end="2024-08-09")
BNB = yf.download(ticker, start="2024-01-01", end="2024-08-09")
DOGE = yf.download(ticker, start="2024-01-01", end="2024-08-09")
SOL = yf.download(ticker, start="2024-01-01", end="2024-08-09")
XLM = yf.download(ticker, start="2024-01-01", end="2024-08-09")
USDT = yf.download(ticker, start="2024-01-01", end="2024-08-09")
UNI = yf.download(ticker, start="2024-01-01", end="2024-08-09")
LINK = yf.download(ticker, start="2024-01-01", end="2024-08-09")
AVAX = yf.download(ticker, start="2024-01-01", end="2024-08-09")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
ETH.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
#
#                Adj Close       Volume
# Date
# 2024-01-01  44167.332031  18426978443
# 2024-01-02  44957.968750  39335274536
# 2024-01-03  42848.175781  46342323118
# 2024-01-04  44179.921875  30448091210
# 2024-01-05  44162.691406  32336029347

# %%
BTC_RD = BTC.rename(columns={'Open':'(BTC)Open','High':'(BTC)High','Low':'(BTC)Low','Close':'(BTC)Close','Adj Close':'(BTC)Adj Close','Volume':'(BTC)Volume'})

# %%
ETH_RD = ETH.rename(columns={'Open':'(ETH)Open','High':'(ETH)High','Low':'(ETH)Low','Close':'(ETH)Close','Adj Close':'(ETH)Adj Close','Volume':'(ETH)Volume'})

# %%
XRP_RD = XRP.rename(columns={'Open':'(XRP)Open','High':'(XRP)High','Low':'(XRP)Low','Close':'(XRP)Close','Adj Close':'(XRP)Adj Close','Volume':'(XRP)Volume'})

# %%
LTC_RD = LTC.rename(columns={'Open':'(LTC)Open','High':'(LTC)High','Low':'(LTC)Low','Close':'(LTC)Close','Adj Close':'(LTC)Adj Close','Volume':'(LTC)Volume'})

# %%
BCH_RD = BCH.rename(columns={'Open':'(BCH)Open','High':'(BCH)High','Low':'(BCH)Low','Close':'(BCH)Close','Adj Close':'(BCH)Adj Close','Volume':'(BCH)Volume'})

# %%
ADA_RD = ADA.rename(columns={'Open':'(ADA)Open','High':'(ADA)High','Low':'(ADA)Low','Close':'(ADA)Close','Adj Close':'(ADA)Adj Close','Volume':'(ADA)Volume'})

# %%
DOT_RD = DOT.rename(columns={'Open':'(DOT)Open','High':'(DOT)High','Low':'(DOT)Low','Close':'(DOT)Close','Adj Close':'(DOT)Adj Close','Volume':'(DOT)Volume'})

# %%
BNB_RD = BNB.rename(columns={'Open':'(BNB)Open','High':'(BNB)High','Low':'(BNB)Low','Close':'(BNB)Close','Adj Close':'(BNB)Adj Close','Volume':'(BNB)Volume'})

# %%
DOGE_RD = DOGE.rename(columns={'Open':'(DOGE)Open','High':'(DOGE)High','Low':'(DOGE)Low','Close':'(DOGE)Close','Adj Close':'(DOGE)Adj Close','Volume':'(DOGE)Volume'})

# %%
SOL_RD = SOL.rename(columns={'Open':'(SOL)Open','High':'(SOL)High','Low':'(SOL)Low','Close':'(SOL)Close','Adj Close':'(SOL)Adj Close','Volume':'(SOL)Volume'})

# %%
XLM_RD = XLM.rename(columns={'Open':'(XLM)Open','High':'(XLM)High','Low':'(XLM)Low','Close':'(XLM)Close','Adj Close':'(XLM)Adj Close','Volume':'(XLM)Volume'})

# %%
USDT_RD = USDT.rename(columns={'Open':'(USDT)Open','High':'(USDT)High','Low':'(USDT)Low','Close':'(USDT)Close','Adj Close':'(USDT)Adj Close','Volume':'(USDT)Volume'})

# %%
UNI_RD = UNI.rename(columns={'Open':'(UNI)Open','High':'(UNI)High','Low':'(UNI)Low','Close':'(UNI)Close','Adj Close':'(UNI)Adj Close','Volume':'(UNI)Volume'})

# %%
LINK_RD = LINK.rename(columns={'Open':'(LINK)Open','High':'(LINK)High','Low':'(LINK)Low','Close':'(LINK)Close','Adj Close':'(LINK)Adj Close','Volume':'(LINK)Volume'})

# %%
AVAX_RD = AVAX.rename(columns={'Open':'(AVAX)Open','High':'(AVAX)High','Low':'(AVAX)Low','Close':'(AVAX)Close','Adj Close':'(AVAX)Adj Close','Volume':'(AVAX)Volume'})

# %% [markdown]
# ### Creamos el DataFrame principal para unificar mediante loc los demas DataFrame para contener las 15 principales criptominedas

# %%
TKOF = BTC_RD

# %%
TKOF.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']] = ETH_RD.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']]

# %%
TKOF.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']] = XRP_RD.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']]

# %%
TKOF.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']] = LTC_RD.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']]

# %%
TKOF.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']] = BCH_RD.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']]

# %%
TKOF.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']] = ADA_RD.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']]

# %%
TKOF.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']] = DOT_RD.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']]

# %%
TKOF.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']] = BNB_RD.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']]

# %%
TKOF.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']] = DOGE_RD.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']]

# %%
TKOF.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']] = XLM_RD.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']]

# %%
TKOF.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']] = SOL_RD.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']]

# %%
TKOF.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']] = USDT_RD.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']]

# %%
TKOF.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']] = UNI_RD.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']]

# %%
TKOF.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']] = LINK_RD.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']]

# %%
TKOF.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']] = AVAX_RD.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']]

# %% [markdown]
# ### Comprobamos la calidad del DataFrame Unificado

# %%
TKOF.shape
# Out:
# (221, 90)

# %%
type(TKOF)
# Out:
# pandas.core.frame.DataFrame

# %%
len(TKOF)
# Out:
# 221

# %%
TKOF.head()
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# 2024-01-02    44957.968750  39335274536  44187.140625  45899.707031
# 2024-01-03    42848.175781  46342323118  44961.601562  45503.242188
# 2024-01-04    44179.921875  30448091210  42855.816406  44770.023438
# 2024-01-05    44162.691406  32336029347  44192.980469  44353.285156
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# ...

# %%
TKOF.tail()
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
# 2024-08-06  53991.347656  57059.917969  53973.273438  56034.316406
# 2024-08-07  56040.632812  57726.882812  54620.507812  55027.460938
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
#
#             (BTC)Adj Close   (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-04    58116.976562   31758917219  60676.093750  61062.988281
# 2024-08-05    53991.457031  108991085584  58110.296875  58268.828125
# 2024-08-06    56034.316406   49300484106  53991.347656  57059.917969
# 2024-08-07    55027.460938   41637562185  56040.632812  57726.882812
# 2024-08-08    61710.136719   45298472567  55030.027344  62673.765625
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# ...

# %%
TKOF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 221 entries, 2024-01-01 to 2024-08-08
# Data columns (total 90 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (BTC)Open        221 non-null    float64
#  1   (BTC)High        221 non-null    float64
#  2   (BTC)Low         221 non-null    float64
#  3   (BTC)Close       221 non-null    float64
#  4   (BTC)Adj Close   221 non-null    float64
#  5   (BTC)Volume      221 non-null    int64
#  6   (ETH)Open        221 non-null    float64
#  7   (ETH)High        221 non-null    float64
#  8   (ETH)Low         221 non-null    float64
#  9   (ETH)Close       221 non-null    float64
#  10  (ETH)Adj Close   221 non-null    float64
#  11  (ETH)Volume      221 non-null    int64
#  12  (XRP)Open        221 non-null    float64
#  13  (XRP)High        221 non-null    float64
#  14  (XRP)Low         221 non-null    float64
#  15  (XRP)Close       221 non-null    float64
# ...

# %%
TKOF.dtypes
# Out:
# (BTC)Open          float64
# (BTC)High          float64
# (BTC)Low           float64
# (BTC)Close         float64
# (BTC)Adj Close     float64
#                     ...
# (AVAX)High         float64
# (AVAX)Low          float64
# (AVAX)Close        float64
# (AVAX)Adj Close    float64
# (AVAX)Volume         int64
# Length: 90, dtype: object

# %%
TKOF.columns.values
# Out:
# array(['(BTC)Open', '(BTC)High', '(BTC)Low', '(BTC)Close',
#        '(BTC)Adj Close', '(BTC)Volume', '(ETH)Open', '(ETH)High',
#        '(ETH)Low', '(ETH)Close', '(ETH)Adj Close', '(ETH)Volume',
#        '(XRP)Open', '(XRP)High', '(XRP)Low', '(XRP)Close',
#        '(XRP)Adj Close', '(XRP)Volume', '(LTC)Open', '(LTC)High',
#        '(LTC)Low', '(LTC)Close', '(LTC)Adj Close', '(LTC)Volume',
#        '(BCH)Open', '(BCH)High', '(BCH)Low', '(BCH)Close',
#        '(BCH)Adj Close', '(BCH)Volume', '(ADA)Open', '(ADA)High',
#        '(ADA)Low', '(ADA)Close', '(ADA)Adj Close', '(ADA)Volume',
#        '(DOT)Open', '(DOT)High', '(DOT)Low', '(DOT)Close',
#        '(DOT)Adj Close', '(DOT)Volume', '(BNB)Open', '(BNB)High',
#        '(BNB)Low', '(BNB)Close', '(BNB)Adj Close', '(BNB)Volume',
#        '(DOGE)Open', '(DOGE)High', '(DOGE)Low', '(DOGE)Close',
#        '(DOGE)Adj Close', '(DOGE)Volume', '(XLM)Open', '(XLM)High',
#        '(XLM)Low', '(XLM)Close', '(XLM)Adj Close', '(XLM)Volume',
# ...

# %%
all_columns_list = TKOF.columns.values.tolist()
all_columns_list
# Out:
# ['(BTC)Open',
#  '(BTC)High',
#  '(BTC)Low',
#  '(BTC)Close',
#  '(BTC)Adj Close',
#  '(BTC)Volume',
#  '(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume',
#  '(XRP)Open',
#  '(XRP)High',
#  '(XRP)Low',
#  '(XRP)Close',
#  '(XRP)Adj Close',
#  '(XRP)Volume',
#  '(LTC)Open',
#  '(LTC)High',
#  '(LTC)Low',
#  '(LTC)Close',
#  '(LTC)Adj Close',
#  '(LTC)Volume',
#  '(BCH)Open',
#  '(BCH)High',
#  '(BCH)Low',
#  '(BCH)Close',
#  '(BCH)Adj Close',
#  '(BCH)Volume',
#  '(ADA)Open',
#  '(ADA)High',
#  '(ADA)Low',
#  '(ADA)Close',
#  '(ADA)Adj Close',
#  '(ADA)Volume',
#  '(DOT)Open',
#  '(DOT)High',
#  '(DOT)Low',
#  '(DOT)Close',
#  '(DOT)Adj Close',
#  '(DOT)Volume',
#  '(BNB)Open',
#  '(BNB)High',
#  '(BNB)Low',
#  '(BNB)Close',
#  '(BNB)Adj Close',
#  '(BNB)Volume',
#  '(DOGE)Open',
#  '(DOGE)High',
#  '(DOGE)Low',
#  '(DOGE)Close',
#  '(DOGE)Adj Close',
#  '(DOGE)Volume',
#  '(XLM)Open',
#  '(XLM)High',
#  '(XLM)Low',
#  '(XLM)Close',
# ...

# %%
TKOF.describe()
# Out:
#           (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  (BTC)Adj Close  \
# count    221.000000    221.000000    221.000000    221.000000      221.000000
# mean   59963.414575  61210.009580  58662.357961  60052.709029    60052.709029
# std     9561.984033   9706.335717   9293.333431   9488.290947     9488.290947
# min    39518.714844  40127.351562  38521.894531  39507.367188    39507.367188
# 25%    52161.675781  52945.050781  51371.628906  52284.875000    52284.875000
# 50%    63510.750000  64610.890625  61752.746094  63512.753906    63512.753906
# 75%    67489.609375  68480.062500  65937.179688  67491.414062    67491.414062
# max    73079.375000  73750.070312  71334.093750  73083.500000    73083.500000
#
#         (BTC)Volume     (ETH)Open     (ETH)High      (ETH)Low    (ETH)Close  \
# count  2.210000e+02    221.000000    221.000000    221.000000    221.000000
# mean   3.197450e+10  59963.414575  61210.009580  58662.357961  60052.709029
# ...

# %%
tickers = "BTC-USD" "ETH-USD", "XRP-USD", "LTC-USD", "BCH-USD", "ADA-USD", "DOT-USD", "BNB-USD", "DOGE-USD", "SOL-USD", "XLM-USD", "USDT-USD", "UNI-USD", "LINK-USD", "AVAX-USD"
BTC_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
ETH_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
XRP_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
LTC_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
BCH_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
ADA_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
DOT_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
BNB_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
DOGE_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
SOL_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
XLM_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
USDT_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
UNI_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
LINK_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
AVAX_0 = yf.download(ticker, start="2024-08-09", end="2024-08-11")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# ### Renombramos columnas de Dataframes agregando su identificador por Criptomoneda

# %%
BTC_RN = BTC_0.rename(columns={'Open':'(BTC)Open','High':'(BTC)High','Low':'(BTC)Low','Close':'(BTC)Close','Adj Close':'(BTC)Adj Close','Volume':'(BTC)Volume'})

# %%
ETH_RN = ETH_0.rename(columns={'Open':'(ETH)Open','High':'(ETH)High','Low':'(ETH)Low','Close':'(ETH)Close','Adj Close':'(ETH)Adj Close','Volume':'(ETH)Volume'})

# %%
XRP_RN = XRP_0.rename(columns={'Open':'(XRP)Open','High':'(XRP)High','Low':'(XRP)Low','Close':'(XRP)Close','Adj Close':'(XRP)Adj Close','Volume':'(XRP)Volume'})

# %%
LTC_RN = LTC_0.rename(columns={'Open':'(LTC)Open','High':'(LTC)High','Low':'(LTC)Low','Close':'(LTC)Close','Adj Close':'(LTC)Adj Close','Volume':'(LTC)Volume'})

# %%
BCH_RN = BCH_0.rename(columns={'Open':'(BCH)Open','High':'(BCH)High','Low':'(BCH)Low','Close':'(BCH)Close','Adj Close':'(BCH)Adj Close','Volume':'(BCH)Volume'})

# %%
ADA_RN = ADA_0.rename(columns={'Open':'(ADA)Open','High':'(ADA)High','Low':'(ADA)Low','Close':'(ADA)Close','Adj Close':'(ADA)Adj Close','Volume':'(ADA)Volume'})

# %%
DOT_RN = DOT_0.rename(columns={'Open':'(DOT)Open','High':'(DOT)High','Low':'(DOT)Low','Close':'(DOT)Close','Adj Close':'(DOT)Adj Close','Volume':'(DOT)Volume'})

# %%
BNB_RN = BNB_0.rename(columns={'Open':'(BNB)Open','High':'(BNB)High','Low':'(BNB)Low','Close':'(BNB)Close','Adj Close':'(BNB)Adj Close','Volume':'(BNB)Volume'})

# %%
DOGE_RN = DOGE_0.rename(columns={'Open':'(DOGE)Open','High':'(DOGE)High','Low':'(DOGE)Low','Close':'(DOGE)Close','Adj Close':'(DOGE)Adj Close','Volume':'(DOGE)Volume'})

# %%
SOL_RN = SOL_0.rename(columns={'Open':'(SOL)Open','High':'(SOL)High','Low':'(SOL)Low','Close':'(SOL)Close','Adj Close':'(SOL)Adj Close','Volume':'(SOL)Volume'})

# %%
XLM_RN = XLM_0.rename(columns={'Open':'(XLM)Open','High':'(XLM)High','Low':'(XLM)Low','Close':'(XLM)Close','Adj Close':'(XLM)Adj Close','Volume':'(XLM)Volume'})

# %%
USDT_RN = USDT_0.rename(columns={'Open':'(USDT)Open','High':'(USDT)High','Low':'(USDT)Low','Close':'(USDT)Close','Adj Close':'(USDT)Adj Close','Volume':'(USDT)Volume'})

# %%
UNI_RN = UNI_0.rename(columns={'Open':'(UNI)Open','High':'(UNI)High','Low':'(UNI)Low','Close':'(UNI)Close','Adj Close':'(UNI)Adj Close','Volume':'(UNI)Volume'})

# %%
LINK_RN = LINK_0.rename(columns={'Open':'(LINK)Open','High':'(LINK)High','Low':'(LINK)Low','Close':'(LINK)Close','Adj Close':'(LINK)Adj Close','Volume':'(LINK)Volume'})

# %%
AVAX_RN = AVAX_0.rename(columns={'Open':'(AVAX)Open','High':'(AVAX)High','Low':'(AVAX)Low','Close':'(AVAX)Close','Adj Close':'(AVAX)Adj Close','Volume':'(AVAX)Volume'})

# %% [markdown]
# ### Unificamos DataFrames de criptomonedas en uno solo

# %%
TKOF_0 = BTC_RN

# %%
TKOF_0.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']] = ETH_RN.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']]

# %%
TKOF_0.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']] = XRP_RN.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']]

# %%
TKOF_0.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']] = LTC_RN.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']]

# %%
TKOF_0.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']] = BCH_RN.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']]

# %%
TKOF_0.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']] = ADA_RN.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']]

# %%
TKOF_0.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']] = DOT_RN.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']]

# %%
TKOF_0.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']] = BNB_RN.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']]

# %%
TKOF_0.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']] = DOGE_RN.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']]

# %%
TKOF_0.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']] = XLM_RN.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']]

# %%
TKOF_0.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']] = SOL_RN.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']]

# %%
TKOF_0.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']] = USDT_RN.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']]

# %%
TKOF_0.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']] = UNI_RN.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']]

# %%
TKOF_0.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']] = LINK_RN.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']]

# %%
TKOF_0.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']] = AVAX_RN.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']]

# %% [markdown]
# ### Comprobamos DataFrame Unificados

# %%
TKOF_0
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60881.230469  61464.511719  60287.566406  60945.812500
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-09    60880.113281  33425553115  61728.207031  61751.863281
# 2024-08-10    60945.812500  15745822278  60881.230469  61464.511719
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# 2024-08-09  59587.859375  60880.113281  ...  59587.859375  60880.113281
# 2024-08-10  60287.566406  60945.812500  ...  60287.566406  60945.812500
#
#             (LINK)Adj Close  (LINK)Volume    (AVAX)Open    (AVAX)High  \
# Date
# 2024-08-09     60880.113281   33425553115  61728.207031  61751.863281
# 2024-08-10     60945.812500   15745822278  60881.230469  61464.511719
#
# ...

# %%
BTC_0 = BTC_0.rename(columns={'Open':'(BTC)Open','High':'(BTC)High','Low':'(BTC)Low','Close':'(BTC)Close','Adj Close':'(BTC)Adj Close','Volume':'(BTC)Volume'})

# %%
BTC_0.head()
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60881.230469  61464.511719  60287.566406  60945.812500
#
#             (BTC)Adj Close  (BTC)Volume
# Date
# 2024-08-09    60880.113281  33425553115
# 2024-08-10    60945.812500  15745822278

# %%
df_1 = TKOF_0

# %%
TKOF.columns.values
# Out:
# array(['(BTC)Open', '(BTC)High', '(BTC)Low', '(BTC)Close',
#        '(BTC)Adj Close', '(BTC)Volume', '(ETH)Open', '(ETH)High',
#        '(ETH)Low', '(ETH)Close', '(ETH)Adj Close', '(ETH)Volume',
#        '(XRP)Open', '(XRP)High', '(XRP)Low', '(XRP)Close',
#        '(XRP)Adj Close', '(XRP)Volume', '(LTC)Open', '(LTC)High',
#        '(LTC)Low', '(LTC)Close', '(LTC)Adj Close', '(LTC)Volume',
#        '(BCH)Open', '(BCH)High', '(BCH)Low', '(BCH)Close',
#        '(BCH)Adj Close', '(BCH)Volume', '(ADA)Open', '(ADA)High',
#        '(ADA)Low', '(ADA)Close', '(ADA)Adj Close', '(ADA)Volume',
#        '(DOT)Open', '(DOT)High', '(DOT)Low', '(DOT)Close',
#        '(DOT)Adj Close', '(DOT)Volume', '(BNB)Open', '(BNB)High',
#        '(BNB)Low', '(BNB)Close', '(BNB)Adj Close', '(BNB)Volume',
#        '(DOGE)Open', '(DOGE)High', '(DOGE)Low', '(DOGE)Close',
#        '(DOGE)Adj Close', '(DOGE)Volume', '(XLM)Open', '(XLM)High',
#        '(XLM)Low', '(XLM)Close', '(XLM)Adj Close', '(XLM)Volume',
# ...

# %%
all_columns_list = TKOF.columns.values.tolist()
all_columns_list
# Out:
# ['(BTC)Open',
#  '(BTC)High',
#  '(BTC)Low',
#  '(BTC)Close',
#  '(BTC)Adj Close',
#  '(BTC)Volume',
#  '(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume',
#  '(XRP)Open',
#  '(XRP)High',
#  '(XRP)Low',
#  '(XRP)Close',
#  '(XRP)Adj Close',
#  '(XRP)Volume',
#  '(LTC)Open',
#  '(LTC)High',
#  '(LTC)Low',
#  '(LTC)Close',
#  '(LTC)Adj Close',
#  '(LTC)Volume',
#  '(BCH)Open',
#  '(BCH)High',
#  '(BCH)Low',
#  '(BCH)Close',
#  '(BCH)Adj Close',
#  '(BCH)Volume',
#  '(ADA)Open',
#  '(ADA)High',
#  '(ADA)Low',
#  '(ADA)Close',
#  '(ADA)Adj Close',
#  '(ADA)Volume',
#  '(DOT)Open',
#  '(DOT)High',
#  '(DOT)Low',
#  '(DOT)Close',
#  '(DOT)Adj Close',
#  '(DOT)Volume',
#  '(BNB)Open',
#  '(BNB)High',
#  '(BNB)Low',
#  '(BNB)Close',
#  '(BNB)Adj Close',
#  '(BNB)Volume',
#  '(DOGE)Open',
#  '(DOGE)High',
#  '(DOGE)Low',
#  '(DOGE)Close',
#  '(DOGE)Adj Close',
#  '(DOGE)Volume',
#  '(XLM)Open',
#  '(XLM)High',
#  '(XLM)Low',
#  '(XLM)Close',
# ...

# %% [markdown]
# ### Agregamos DataFrame del ultimo historico para actualizar DataFrame principal

# %%
TKOF.head()
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# 2024-01-02    44957.968750  39335274536  44187.140625  45899.707031
# 2024-01-03    42848.175781  46342323118  44961.601562  45503.242188
# 2024-01-04    44179.921875  30448091210  42855.816406  44770.023438
# 2024-01-05    44162.691406  32336029347  44192.980469  44353.285156
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# ...

# %%
TKOF.tail()
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
# 2024-08-06  53991.347656  57059.917969  53973.273438  56034.316406
# 2024-08-07  56040.632812  57726.882812  54620.507812  55027.460938
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
#
#             (BTC)Adj Close   (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-04    58116.976562   31758917219  60676.093750  61062.988281
# 2024-08-05    53991.457031  108991085584  58110.296875  58268.828125
# 2024-08-06    56034.316406   49300484106  53991.347656  57059.917969
# 2024-08-07    55027.460938   41637562185  56040.632812  57726.882812
# 2024-08-08    61710.136719   45298472567  55030.027344  62673.765625
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# ...

# %%
df = TKOF

# %%
df
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# ...                  ...           ...           ...           ...
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
# 2024-08-05  58110.296875  58268.828125  49121.238281  53991.457031
# 2024-08-06  53991.347656  57059.917969  53973.273438  56034.316406
# 2024-08-07  56040.632812  57726.882812  54620.507812  55027.460938
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
#
#             (BTC)Adj Close   (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031   18426978443  42280.234375  44175.437500
# ...

# %%
TKOF_0
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60881.230469  61464.511719  60287.566406  60945.812500
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-09    60880.113281  33425553115  61728.207031  61751.863281
# 2024-08-10    60945.812500  15745822278  60881.230469  61464.511719
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# 2024-08-09  59587.859375  60880.113281  ...  59587.859375  60880.113281
# 2024-08-10  60287.566406  60945.812500  ...  60287.566406  60945.812500
#
#             (LINK)Adj Close  (LINK)Volume    (AVAX)Open    (AVAX)High  \
# Date
# 2024-08-09     60880.113281   33425553115  61728.207031  61751.863281
# 2024-08-10     60945.812500   15745822278  60881.230469  61464.511719
#
# ...

# %%
df_1 = TKOF_0

# %%
df_1
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60881.230469  61464.511719  60287.566406  60945.812500
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-09    60880.113281  33425553115  61728.207031  61751.863281
# 2024-08-10    60945.812500  15745822278  60881.230469  61464.511719
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# 2024-08-09  59587.859375  60880.113281  ...  59587.859375  60880.113281
# 2024-08-10  60287.566406  60945.812500  ...  60287.566406  60945.812500
#
#             (LINK)Adj Close  (LINK)Volume    (AVAX)Open    (AVAX)High  \
# Date
# 2024-08-09     60880.113281   33425553115  61728.207031  61751.863281
# 2024-08-10     60945.812500   15745822278  60881.230469  61464.511719
#
# ...

# %%
filas_a_agregar = df_1.iloc[0:220]

# %%
df = pd.concat([df,filas_a_agregar])

# %%
df.head()
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# 2024-01-02    44957.968750  39335274536  44187.140625  45899.707031
# 2024-01-03    42848.175781  46342323118  44961.601562  45503.242188
# 2024-01-04    44179.921875  30448091210  42855.816406  44770.023438
# 2024-01-05    44162.691406  32336029347  44192.980469  44353.285156
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# ...

# %%
df.tail()
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-06  53991.347656  57059.917969  53973.273438  56034.316406
# 2024-08-07  56040.632812  57726.882812  54620.507812  55027.460938
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60881.230469  61464.511719  60287.566406  60945.812500
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-06    56034.316406  49300484106  53991.347656  57059.917969
# 2024-08-07    55027.460938  41637562185  56040.632812  57726.882812
# 2024-08-08    61710.136719  45298472567  55030.027344  62673.765625
# 2024-08-09    60880.113281  33425553115  61728.207031  61751.863281
# 2024-08-10    60945.812500  15745822278  60881.230469  61464.511719
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# ...

# %%
df.shape
# Out:
# (223, 90)

# %% [markdown]
# ### Descargamos historicos 11 a 12 de Agosto para actualizart DataFrtame principal

# %%
tickers = "BTC-USD" "ETH-USD", "XRP-USD", "LTC-USD", "BCH-USD", "ADA-USD", "DOT-USD", "BNB-USD", "DOGE-USD", "SOL-USD", "XLM-USD", "USDT-USD", "UNI-USD", "LINK-USD", "AVAX-USD"
BTC_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
ETH_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
XRP_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
LTC_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
BCH_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
ADA_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
DOT_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
BNB_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
DOGE_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
SOL_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
XLM_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
USDT_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
UNI_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
LINK_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
AVAX_1 = yf.download(ticker, start="2024-08-11", end="2024-08-13")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
BTC_1
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-11  60944.890625  61778.660156  58348.824219  58719.484375
# 2024-08-12  58719.394531  60680.332031  57688.898438  59354.515625
#
#                Adj Close       Volume
# Date
# 2024-08-11  58719.484375  22759754812
# 2024-08-12  59354.515625  37078637820

# %% [markdown]
# ### Renombramos DataFrames con su indicador por criptomoneda

# %%
BTC_RE = BTC_1.rename(columns={'Open':'(BTC)Open','High':'(BTC)High','Low':'(BTC)Low','Close':'(BTC)Close','Adj Close':'(BTC)Adj Close','Volume':'(BTC)Volume'})

# %%
ETH_RE = ETH_1.rename(columns={'Open':'(ETH)Open','High':'(ETH)High','Low':'(ETH)Low','Close':'(ETH)Close','Adj Close':'(ETH)Adj Close','Volume':'(ETH)Volume'})

# %%
XRP_RE = XRP_1.rename(columns={'Open':'(XRP)Open','High':'(XRP)High','Low':'(XRP)Low','Close':'(XRP)Close','Adj Close':'(XRP)Adj Close','Volume':'(XRP)Volume'})

# %%
LTC_RE = LTC_1.rename(columns={'Open':'(LTC)Open','High':'(LTC)High','Low':'(LTC)Low','Close':'(LTC)Close','Adj Close':'(LTC)Adj Close','Volume':'(LTC)Volume'})

# %%
BCH_RE = BCH_1.rename(columns={'Open':'(BCH)Open','High':'(BCH)High','Low':'(BCH)Low','Close':'(BCH)Close','Adj Close':'(BCH)Adj Close','Volume':'(BCH)Volume'})

# %%
ADA_RE = ADA_1.rename(columns={'Open':'(ADA)Open','High':'(ADA)High','Low':'(ADA)Low','Close':'(ADA)Close','Adj Close':'(ADA)Adj Close','Volume':'(ADA)Volume'})

# %%
DOT_RE = DOT_1.rename(columns={'Open':'(DOT)Open','High':'(DOT)High','Low':'(DOT)Low','Close':'(DOT)Close','Adj Close':'(DOT)Adj Close','Volume':'(DOT)Volume'})

# %%
BNB_RE = BNB_1.rename(columns={'Open':'(BNB)Open','High':'(BNB)High','Low':'(BNB)Low','Close':'(BNB)Close','Adj Close':'(BNB)Adj Close','Volume':'(BNB)Volume'})

# %%
DOGE_RE = DOGE_1.rename(columns={'Open':'(DOGE)Open','High':'(DOGE)High','Low':'(DOGE)Low','Close':'(DOGE)Close','Adj Close':'(DOGE)Adj Close','Volume':'(DOGE)Volume'})

# %%
SOL_RE = SOL_1.rename(columns={'Open':'(SOL)Open','High':'(SOL)High','Low':'(SOL)Low','Close':'(SOL)Close','Adj Close':'(SOL)Adj Close','Volume':'(SOL)Volume'})

# %%
XLM_RE = XLM_1.rename(columns={'Open':'(XLM)Open','High':'(XLM)High','Low':'(XLM)Low','Close':'(XLM)Close','Adj Close':'(XLM)Adj Close','Volume':'(XLM)Volume'})

# %%
USDT_RE = USDT_1.rename(columns={'Open':'(USDT)Open','High':'(USDT)High','Low':'(USDT)Low','Close':'(USDT)Close','Adj Close':'(USDT)Adj Close','Volume':'(USDT)Volume'})

# %%
UNI_RE = UNI_1.rename(columns={'Open':'(UNI)Open','High':'(UNI)High','Low':'(UNI)Low','Close':'(UNI)Close','Adj Close':'(UNI)Adj Close','Volume':'(UNI)Volume'})

# %%
LINK_RE = LINK_1.rename(columns={'Open':'(LINK)Open','High':'(LINK)High','Low':'(LINK)Low','Close':'(LINK)Close','Adj Close':'(LINK)Adj Close','Volume':'(LINK)Volume'})

# %%
AVAX_RE = AVAX_1.rename(columns={'Open':'(AVAX)Open','High':'(AVAX)High','Low':'(AVAX)Low','Close':'(AVAX)Close','Adj Close':'(AVAX)Adj Close','Volume':'(AVAX)Volume'})

# %% [markdown]
# ### Unificamos DataFrame con historicos de 11 a 12 de Agosto

# %%
TKOF_1 = BTC_RE

# %%
TKOF_1.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']] = ETH_RE.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']]

# %%
TKOF_1.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']] = XRP_RE.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']]

# %%
TKOF_1.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']] = LTC_RE.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']]

# %%
TKOF_1.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']] = BCH_RE.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']]

# %%
TKOF_1.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']] = ADA_RE.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']]

# %%
TKOF_1.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']] = DOT_RE.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']]

# %%
TKOF_1.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']] = BNB_RE.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']]

# %%
TKOF_1.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']] = DOGE_RE.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']]

# %%
TKOF_1.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']] = XLM_RE.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']]

# %%
TKOF_1.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']] = SOL_RE.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']]

# %%
TKOF_1.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']] = USDT_RE.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']]

# %%
TKOF_1.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']] = UNI_RE.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']]

# %%
TKOF_1.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']] = LINK_RE.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']]

# %%
TKOF_1.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']] = AVAX_RE.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']]

# %%
TKOF_1
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-11  60944.890625  61778.660156  58348.824219  58719.484375
# 2024-08-12  58719.394531  60680.332031  57688.898438  59354.515625
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-11    58719.484375  22759754812  60944.890625  61778.660156
# 2024-08-12    59354.515625  37078637820  58719.394531  60680.332031
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# 2024-08-11  58348.824219  58719.484375  ...  58348.824219  58719.484375
# 2024-08-12  57688.898438  59354.515625  ...  57688.898438  59354.515625
#
#             (LINK)Adj Close  (LINK)Volume    (AVAX)Open    (AVAX)High  \
# Date
# 2024-08-11     58719.484375   22759754812  60944.890625  61778.660156
# 2024-08-12     59354.515625   37078637820  58719.394531  60680.332031
#
# ...

# %%
TKOF_1.shape
# Out:
# (2, 90)

# %%
TKOF_1.columns.values
# Out:
# array(['(BTC)Open', '(BTC)High', '(BTC)Low', '(BTC)Close',
#        '(BTC)Adj Close', '(BTC)Volume', '(ETH)Open', '(ETH)High',
#        '(ETH)Low', '(ETH)Close', '(ETH)Adj Close', '(ETH)Volume',
#        '(XRP)Open', '(XRP)High', '(XRP)Low', '(XRP)Close',
#        '(XRP)Adj Close', '(XRP)Volume', '(LTC)Open', '(LTC)High',
#        '(LTC)Low', '(LTC)Close', '(LTC)Adj Close', '(LTC)Volume',
#        '(BCH)Open', '(BCH)High', '(BCH)Low', '(BCH)Close',
#        '(BCH)Adj Close', '(BCH)Volume', '(ADA)Open', '(ADA)High',
#        '(ADA)Low', '(ADA)Close', '(ADA)Adj Close', '(ADA)Volume',
#        '(DOT)Open', '(DOT)High', '(DOT)Low', '(DOT)Close',
#        '(DOT)Adj Close', '(DOT)Volume', '(BNB)Open', '(BNB)High',
#        '(BNB)Low', '(BNB)Close', '(BNB)Adj Close', '(BNB)Volume',
#        '(DOGE)Open', '(DOGE)High', '(DOGE)Low', '(DOGE)Close',
#        '(DOGE)Adj Close', '(DOGE)Volume', '(XLM)Open', '(XLM)High',
#        '(XLM)Low', '(XLM)Close', '(XLM)Adj Close', '(XLM)Volume',
# ...

# %% [markdown]
# ### Unificamos actulizacion a DataFrame principal

# %%
df_2 = TKOF_1

# %%
df_2
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-11  60944.890625  61778.660156  58348.824219  58719.484375
# 2024-08-12  58719.394531  60680.332031  57688.898438  59354.515625
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-11    58719.484375  22759754812  60944.890625  61778.660156
# 2024-08-12    59354.515625  37078637820  58719.394531  60680.332031
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# 2024-08-11  58348.824219  58719.484375  ...  58348.824219  58719.484375
# 2024-08-12  57688.898438  59354.515625  ...  57688.898438  59354.515625
#
#             (LINK)Adj Close  (LINK)Volume    (AVAX)Open    (AVAX)High  \
# Date
# 2024-08-11     58719.484375   22759754812  60944.890625  61778.660156
# 2024-08-12     59354.515625   37078637820  58719.394531  60680.332031
#
# ...

# %%
filas_a_agregar = df_2.iloc[0:222]

# %%
df = pd.concat([df,filas_a_agregar])

# %%
df
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# ...                  ...           ...           ...           ...
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60881.230469  61464.511719  60287.566406  60945.812500
# 2024-08-11  60944.890625  61778.660156  58348.824219  58719.484375
# 2024-08-12  58719.394531  60680.332031  57688.898438  59354.515625
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# ...

# %%
tickers = "BTC-USD" "ETH-USD", "XRP-USD", "LTC-USD", "BCH-USD", "ADA-USDT", "DOT-USD", "BNB-USD", "DOGE-USD", "SOL-USD", "XLM-USD", "USDT-USD", "UNI-USD", "LINK-USD", "AVAX-USD"
BTC_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
ETH_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
XRP_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
LTC_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
BCH_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
ADA_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
DOT_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
BNB_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
DOGE_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
SOL_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
XLM_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
USDT_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
UNI_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
LINK_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
AVAX_2 = yf.download(ticker, start="2024-08-13", end="2024-08-16")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
BTC_2
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-13  59356.207031  61572.398438  58506.253906  60609.566406
# 2024-08-14  60611.050781  61687.757812  58472.875000  58737.269531
# 2024-08-15  58733.261719  59838.648438  56161.593750  57560.097656
#
#                Adj Close       Volume
# Date
# 2024-08-13  60609.566406  30327698167
# 2024-08-14  58737.269531  29961696180
# 2024-08-15  57560.097656  35682112440

# %% [markdown]
# ### Renombramos DataFrames con su indicador por criptomoneda

# %%
BTC_RA = BTC_2.rename(columns={'Open':'(BTC)Open','High':'(BTC)High','Low':'(BTC)Low','Close':'(BTC)Close','Adj Close':'(BTC)Adj Close','Volume':'(BTC)Volume'})

# %%
ETH_RA = ETH_2.rename(columns={'Open':'(ETH)Open','High':'(ETH)High','Low':'(ETH)Low','Close':'(ETH)Close','Adj Close':'(ETH)Adj Close','Volume':'(ETH)Volume'})

# %%
XRP_RA = XRP_2.rename(columns={'Open':'(XRP)Open','High':'(XRP)High','Low':'(XRP)Low','Close':'(XRP)Close','Adj Close':'(XRP)Adj Close','Volume':'(XRP)Volume'})

# %%
LTC_RA = LTC_2.rename(columns={'Open':'(LTC)Open','High':'(LTC)High','Low':'(LTC)Low','Close':'(LTC)Close','Adj Close':'(LTC)Adj Close','Volume':'(LTC)Volume'})

# %%
BCH_RA = BCH_2.rename(columns={'Open':'(BCH)Open','High':'(BCH)High','Low':'(BCH)Low','Close':'(BCH)Close','Adj Close':'(BCH)Adj Close','Volume':'(BCH)Volume'})

# %%
ADA_RA = ADA_2.rename(columns={'Open':'(ADA)Open','High':'(ADA)High','Low':'(ADA)Low','Close':'(ADA)Close','Adj Close':'(ADA)Adj Close','Volume':'(ADA)Volume'})

# %%
DOT_RA = DOT_2.rename(columns={'Open':'(DOT)Open','High':'(DOT)High','Low':'(DOT)Low','Close':'(DOT)Close','Adj Close':'(DOT)Adj Close','Volume':'(DOT)Volume'})

# %%
BNB_RA = BNB_2.rename(columns={'Open':'(BNB)Open','High':'(BNB)High','Low':'(BNB)Low','Close':'(BNB)Close','Adj Close':'(BNB)Adj Close','Volume':'(BNB)Volume'})

# %%
DOGE_RA = DOGE_2.rename(columns={'Open':'(DOGE)Open','High':'(DOGE)High','Low':'(DOGE)Low','Close':'(DOGE)Close','Adj Close':'(DOGE)Adj Close','Volume':'(DOGE)Volume'})

# %%
SOL_RA = SOL_2.rename(columns={'Open':'(SOL)Open','High':'(SOL)High','Low':'(SOL)Low','Close':'(SOL)Close','Adj Close':'(SOL)Adj Close','Volume':'(SOL)Volume'})

# %%
XLM_RA = XLM_2.rename(columns={'Open':'(XLM)Open','High':'(XLM)High','Low':'(XLM)Low','Close':'(XLM)Close','Adj Close':'(XLM)Adj Close','Volume':'(XLM)Volume'})

# %%
USDT_RA = USDT_2.rename(columns={'Open':'(USDT)Open','High':'(USDT)High','Low':'(USDT)Low','Close':'(USDT)Close','Adj Close':'(USDT)Adj Close','Volume':'(USDT)Volume'})

# %%
UNI_RA = UNI_2.rename(columns={'Open':'(UNI)Open','High':'(UNI)High','Low':'(UNI)Low','Close':'(UNI)Close','Adj Close':'(UNI)Adj Close','Volume':'(UNI)Volume'})

# %%
LINK_RA = LINK_2.rename(columns={'Open':'(LINK)Open','High':'(LINK)High','Low':'(LINK)Low','Close':'(LINK)Close','Adj Close':'(LINK)Adj Close','Volume':'(LINK)Volume'})

# %%
AVAX_RA = AVAX_2.rename(columns={'Open':'(AVAX)Open','High':'(AVAX)High','Low':'(AVAX)Low','Close':'(AVAX)Close','Adj Close':'(AVAX)Adj Close','Volume':'(AVAX)Volume'})

# %% [markdown]
# ### Unificamos DataFrame con historicos de 12 a 15 de Agosto

# %%
TKOF_2 = BTC_RA

# %%
TKOF_2.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']] = ETH_RA.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']]

# %%
TKOF_2.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']] = XRP_RA.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']]

# %%
TKOF_2.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']] = LTC_RA.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']]

# %%
TKOF_2.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']] = BCH_RA.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']]

# %%
TKOF_2.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']] = ADA_RA.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']]

# %%
TKOF_2.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']] = DOT_RA.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']]

# %%
TKOF_2.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']] = BNB_RA.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']]

# %%
TKOF_2.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']] = DOGE_RA.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']]

# %%
TKOF_2.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']] = XLM_RA.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']]

# %%
TKOF_2.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']] = SOL_RA.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']]

# %%
TKOF_2.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']] = USDT_RA.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']]

# %%
TKOF_2.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']] = UNI_RA.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']]

# %%
TKOF_2.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']] = LINK_RA.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']]

# %%
TKOF_2.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']] = AVAX_RA.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']]

# %%
TKOF_2.shape
# Out:
# (3, 90)

# %%
df.shape
# Out:
# (225, 90)

# %%
df
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# ...                  ...           ...           ...           ...
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60881.230469  61464.511719  60287.566406  60945.812500
# 2024-08-11  60944.890625  61778.660156  58348.824219  58719.484375
# 2024-08-12  58719.394531  60680.332031  57688.898438  59354.515625
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# ...

# %%
TKOF_2
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-13  59356.207031  61572.398438  58506.253906  60609.566406
# 2024-08-14  60611.050781  61687.757812  58472.875000  58737.269531
# 2024-08-15  58733.261719  59838.648438  56161.593750  57560.097656
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-08-13    60609.566406  30327698167  59356.207031  61572.398438
# 2024-08-14    58737.269531  29961696180  60611.050781  61687.757812
# 2024-08-15    57560.097656  35682112440  58733.261719  59838.648438
#
#                 (ETH)Low    (ETH)Close  ...     (LINK)Low   (LINK)Close  \
# Date                                    ...
# 2024-08-13  58506.253906  60609.566406  ...  58506.253906  60609.566406
# 2024-08-14  58472.875000  58737.269531  ...  58472.875000  58737.269531
# 2024-08-15  56161.593750  57560.097656  ...  56161.593750  57560.097656
#
# ...

# %%
df
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# ...                  ...           ...           ...           ...
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60881.230469  61464.511719  60287.566406  60945.812500
# 2024-08-11  60944.890625  61778.660156  58348.824219  58719.484375
# 2024-08-12  58719.394531  60680.332031  57688.898438  59354.515625
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# ...

# %%
df_3 = TKOF_2

# %%
filas_a_agregar = df_3.iloc[0:224]

# %%
df = pd.concat([df,filas_a_agregar])

# %%
df
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# ...                  ...           ...           ...           ...
# 2024-08-11  60944.890625  61778.660156  58348.824219  58719.484375
# 2024-08-12  58719.394531  60680.332031  57688.898438  59354.515625
# 2024-08-13  59356.207031  61572.398438  58506.253906  60609.566406
# 2024-08-14  60611.050781  61687.757812  58472.875000  58737.269531
# 2024-08-15  58733.261719  59838.648438  56161.593750  57560.097656
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# ...

# %%
df.to_csv('../CRIPTO/Datasets/continuacionA.csv')

# %% [markdown]
# ### Descargamos historicos 16 de Agosto al 25 de septiembre para actualizart DataFrtame principal

# %%
tickers = "BTC-USD" "ETH-USD", "XRP-USD", "LTC-USD", "BCH-USD", "ADA-USD", "DOT-USD", "BNB-USD", "DOGE-USD", "SOL-USD", "XLM-USD", "USDT-USD", "UNI-USD", "LINK-USD", "AVAX-USD"
BTC_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
ETH_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
XRP_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
LTC_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
BCH_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
ADA_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
DOT_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
BNB_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
DOGE_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
SOL_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
XLM_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
USDT_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
UNI_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
LINK_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
AVAX_3 = yf.download(ticker, start="2024-08-16", end="2024-09-25")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
BTC_3
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-08-16  57560.273438  59847.359375  57110.019531  58894.105469
# 2024-08-17  58893.531250  59694.667969  58814.832031  59478.972656
# 2024-08-18  59468.132812  60262.718750  58445.402344  58483.964844
# 2024-08-19  58480.710938  59612.660156  57864.710938  59493.453125
# 2024-08-20  59493.453125  61396.328125  58610.882812  59012.792969
# 2024-08-21  59014.988281  61834.351562  58823.445312  61175.191406
# 2024-08-22  61168.316406  61408.109375  59815.253906  60381.914062
# 2024-08-23  60380.953125  64947.062500  60372.050781  64094.355469
# 2024-08-24  64103.871094  64513.789062  63619.917969  64178.992188
# 2024-08-25  64176.367188  64996.421875  63833.519531  64333.542969
# 2024-08-26  64342.226562  64489.707031  62849.558594  62880.660156
# 2024-08-27  62879.707031  63210.796875  58116.750000  59504.132812
# 2024-08-28  59507.925781  60236.449219  57890.675781  59027.625000
# ...

# %% [markdown]
# ### Renombramos DataFrames con su indicador por criptomoneda

# %%
BTC_R = BTC_3.rename(columns={'Open':'(BTC)Open','High':'(BTC)High','Low':'(BTC)Low','Close':'(BTC)Close','Adj Close':'(BTC)Adj Close','Volume':'(BTC)Volume'})

# %%
ETH_R = ETH_3.rename(columns={'Open':'(ETH)Open','High':'(ETH)High','Low':'(ETH)Low','Close':'(ETH)Close','Adj Close':'(ETH)Adj Close','Volume':'(ETH)Volume'})

# %%
XRP_R = XRP_3.rename(columns={'Open':'(XRP)Open','High':'(XRP)High','Low':'(XRP)Low','Close':'(XRP)Close','Adj Close':'(XRP)Adj Close','Volume':'(XRP)Volume'})

# %%
LTC_R = LTC_3.rename(columns={'Open':'(LTC)Open','High':'(LTC)High','Low':'(LTC)Low','Close':'(LTC)Close','Adj Close':'(LTC)Adj Close','Volume':'(LTC)Volume'})

# %%
BCH_R = BCH_3.rename(columns={'Open':'(BCH)Open','High':'(BCH)High','Low':'(BCH)Low','Close':'(BCH)Close','Adj Close':'(BCH)Adj Close','Volume':'(BCH)Volume'})

# %%
ADA_R = ADA_3.rename(columns={'Open':'(ADA)Open','High':'(ADA)High','Low':'(ADA)Low','Close':'(ADA)Close','Adj Close':'(ADA)Adj Close','Volume':'(ADA)Volume'})

# %%
DOT_R = DOT_3.rename(columns={'Open':'(DOT)Open','High':'(DOT)High','Low':'(DOT)Low','Close':'(DOT)Close','Adj Close':'(DOT)Adj Close','Volume':'(DOT)Volume'})

# %%
BNB_R = BNB_3.rename(columns={'Open':'(BNB)Open','High':'(BNB)High','Low':'(BNB)Low','Close':'(BNB)Close','Adj Close':'(BNB)Adj Close','Volume':'(BNB)Volume'})

# %%
DOGE_R = DOGE_3.rename(columns={'Open':'(DOGE)Open','High':'(DOGE)High','Low':'(DOGE)Low','Close':'(DOGE)Close','Adj Close':'(DOGE)Adj Close','Volume':'(DOGE)Volume'})

# %%
SOL_R = SOL_3.rename(columns={'Open':'(SOL)Open','High':'(SOL)High','Low':'(SOL)Low','Close':'(SOL)Close','Adj Close':'(SOL)Adj Close','Volume':'(SOL)Volume'})

# %%
XLM_R = XLM_3.rename(columns={'Open':'(XLM)Open','High':'(XLM)High','Low':'(XLM)Low','Close':'(XLM)Close','Adj Close':'(XLM)Adj Close','Volume':'(XLM)Volume'})

# %%
USDT_R = USDT_3.rename(columns={'Open':'(USDT)Open','High':'(USDT)High','Low':'(USDT)Low','Close':'(USDT)Close','Adj Close':'(USDT)Adj Close','Volume':'(USDT)Volume'})

# %%
UNI_R = UNI_3.rename(columns={'Open':'(UNI)Open','High':'(UNI)High','Low':'(UNI)Low','Close':'(UNI)Close','Adj Close':'(UNI)Adj Close','Volume':'(UNI)Volume'})

# %%
LINK_R = LINK_3.rename(columns={'Open':'(LINK)Open','High':'(LINK)High','Low':'(LINK)Low','Close':'(LINK)Close','Adj Close':'(LINK)Adj Close','Volume':'(LINK)Volume'})

# %%
AVAX_R = AVAX_3.rename(columns={'Open':'(AVAX)Open','High':'(AVAX)High','Low':'(AVAX)Low','Close':'(AVAX)Close','Adj Close':'(AVAX)Adj Close','Volume':'(AVAX)Volume'})

# %% [markdown]
# ### Unificamos DataFrame con historicos deL 16 de Agosto al 25 de septiembre

# %%
TKOF_3 = BTC_R

# %%
TKOF_3.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']] = ETH_R.loc[:,['(ETH)Open','(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']]

# %%
TKOF_3.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']] = XRP_R.loc[:,['(XRP)Open','(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']]

# %%
TKOF_3.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']] = LTC_R.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']]

# %%
TKOF_3.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']] = BCH_R.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']]

# %%
TKOF_3.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']] = ADA_R.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']]

# %%
TKOF_3.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']] = DOT_R.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']]

# %%
TKOF_3.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']] = BNB_R.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']]

# %%
TKOF_3.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']] = DOGE_R.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']]

# %%
TKOF_3.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']] = XLM_R.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']]

# %%
TKOF_3.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']] = SOL_R.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']]

# %%
TKOF_3.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']] = USDT_R.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']]

# %%
TKOF_3.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']] = UNI_R.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']]

# %%
TKOF_3.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']] = LINK_R.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']]

# %%
TKOF_3.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']] = AVAX_R.loc[:,['(AVAX)Open','(AVAX)High','(AVAX)Low','(AVAX)Close','(AVAX)Adj Close','(AVAX)Volume']]

# %%
TKOF_3.shape
# Out:
# (40, 90)

# %%
df.shape
# Out:
# (228, 90)

# %%
df
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# ...                  ...           ...           ...           ...
# 2024-08-11  60944.890625  61778.660156  58348.824219  58719.484375
# 2024-08-12  58719.394531  60680.332031  57688.898438  59354.515625
# 2024-08-13  59356.207031  61572.398438  58506.253906  60609.566406
# 2024-08-14  60611.050781  61687.757812  58472.875000  58737.269531
# 2024-08-15  58733.261719  59838.648438  56161.593750  57560.097656
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# ...

# %%
TKOF_3
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-16  57560.273438  59847.359375  57110.019531  58894.105469
# 2024-08-17  58893.531250  59694.667969  58814.832031  59478.972656
# 2024-08-18  59468.132812  60262.718750  58445.402344  58483.964844
# 2024-08-19  58480.710938  59612.660156  57864.710938  59493.453125
# 2024-08-20  59493.453125  61396.328125  58610.882812  59012.792969
# 2024-08-21  59014.988281  61834.351562  58823.445312  61175.191406
# 2024-08-22  61168.316406  61408.109375  59815.253906  60381.914062
# 2024-08-23  60380.953125  64947.062500  60372.050781  64094.355469
# 2024-08-24  64103.871094  64513.789062  63619.917969  64178.992188
# 2024-08-25  64176.367188  64996.421875  63833.519531  64333.542969
# 2024-08-26  64342.226562  64489.707031  62849.558594  62880.660156
# 2024-08-27  62879.707031  63210.796875  58116.750000  59504.132812
# 2024-08-28  59507.925781  60236.449219  57890.675781  59027.625000
# ...

# %%
df_4 = TKOF_3

# %%
filas_a_agregar = df_4.iloc[0:227]

# %%
df = pd.concat([df,filas_a_agregar])

# %%
df
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
# ...                  ...           ...           ...           ...
# 2024-09-20  62941.425781  64119.531250  62364.605469  63192.976562
# 2024-09-21  63184.339844  63543.359375  62783.105469  63394.839844
# 2024-09-22  63396.804688  63993.421875  62440.726562  63648.710938
# 2024-09-23  63643.101562  64733.558594  62628.078125  63329.800781
# 2024-09-24  63326.839844  64695.214844  62737.417969  64301.968750
#
#             (BTC)Adj Close  (BTC)Volume     (ETH)Open     (ETH)High  \
# Date
# 2024-01-01    44167.332031  18426978443  42280.234375  44175.437500
# ...

# %%
df.tail(41)
# Out:
#                (BTC)Open     (BTC)High      (BTC)Low    (BTC)Close  \
# Date
# 2024-08-15  58733.261719  59838.648438  56161.593750  57560.097656
# 2024-08-16  57560.273438  59847.359375  57110.019531  58894.105469
# 2024-08-17  58893.531250  59694.667969  58814.832031  59478.972656
# 2024-08-18  59468.132812  60262.718750  58445.402344  58483.964844
# 2024-08-19  58480.710938  59612.660156  57864.710938  59493.453125
# 2024-08-20  59493.453125  61396.328125  58610.882812  59012.792969
# 2024-08-21  59014.988281  61834.351562  58823.445312  61175.191406
# 2024-08-22  61168.316406  61408.109375  59815.253906  60381.914062
# 2024-08-23  60380.953125  64947.062500  60372.050781  64094.355469
# 2024-08-24  64103.871094  64513.789062  63619.917969  64178.992188
# 2024-08-25  64176.367188  64996.421875  63833.519531  64333.542969
# 2024-08-26  64342.226562  64489.707031  62849.558594  62880.660156
# 2024-08-27  62879.707031  63210.796875  58116.750000  59504.132812
# ...

# %%
df.to_csv('../CRIPTO/Datasets/continuacionA.csv')
