# %% [markdown]
# <a href="https://colab.research.google.com/github/CODING-racer/criptobot/blob/main/Analisis_II_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#

# %%
df_Criptos = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CRIPTOS.csv')

# %%
df_Criptos.head(21)
# Out:
#     (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 0    0.136576   0.137347  0.134819    0.136937        0.136937    385407083
# 1    0.136940   0.138023  0.126495    0.128889        0.128889    960646592
# 2    0.128866   0.129103  0.115392    0.122296        0.122296   1413960450
# 3    0.122279   0.126508  0.121579    0.122341        0.122341    642487745
# 4    0.122341   0.128266  0.121454    0.124419        0.124419    734399819
# 5    0.124430   0.125500  0.121617    0.124029        0.124029    598393023
# 6    0.124038   0.125365  0.122959    0.123789        0.123789    328642106
# 7    0.123783   0.126120  0.121827    0.122257        0.122257    429188641
# 8    0.122249   0.123675  0.114731    0.119043        0.119043    951099440
# 9    0.119033   0.128236  0.118895    0.126153        0.126153    783244352
# 10   0.126150   0.128522  0.121920    0.122679        0.122679    526276880
# ...

# %%
df_Criptos.shape
# Out:
# (40, 90)

# %%
df_Criptos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 90 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (BTC)Open        40 non-null     float64
#  1   (BTC)High        40 non-null     float64
#  2   (BTC)Low         40 non-null     float64
#  3   (BTC)Close       40 non-null     float64
#  4   (BTC)Adj Close   40 non-null     float64
#  5   (BTC)Volume      40 non-null     int64
#  6   (ETH)Open        40 non-null     float64
#  7   (ETH)High        40 non-null     float64
#  8   (ETH)Low         40 non-null     float64
#  9   (ETH)Close       40 non-null     float64
#  10  (ETH)Adj Close   40 non-null     float64
#  11  (ETH)Volume      40 non-null     int64
#  12  (XRP)Open        40 non-null     float64
#  13  (XRP)High        40 non-null     float64
#  14  (XRP)Low         40 non-null     float64
#  15  (XRP)Close       40 non-null     float64
# ...

# %%
df_Criptos.describe()
# Out:
#        (BTC)Open  (BTC)High   (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# count  40.000000  40.000000  40.000000   40.000000       40.000000
# mean    0.121335   0.124677   0.117277    0.121004        0.121004
# std     0.009580   0.009361   0.009403    0.009261        0.009261
# min     0.104235   0.106418   0.093795    0.104232        0.104232
# 25%     0.114997   0.118335   0.110374    0.114990        0.114990
# 50%     0.122733   0.125778   0.120444    0.122734        0.122734
# 75%     0.125644   0.128330   0.122386    0.125291        0.125291
# max     0.140167   0.143087   0.136214    0.140169        0.140169
#
#         (BTC)Volume  (ETH)Open  (ETH)High   (ETH)Low  (ETH)Close  ...  \
# count  4.000000e+01  40.000000  40.000000  40.000000   40.000000  ...
# mean   7.591183e+08   0.121335   0.124677   0.117277    0.121004  ...
# std    3.298385e+08   0.009580   0.009361   0.009403    0.009261  ...
# min    2.853912e+08   0.104235   0.106418   0.093795    0.104232  ...
# ...

# %%
df_Criptos.tail()
# Out:
#     (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 35   0.134430   0.143087  0.126405    0.140169        0.140169   1229665449
# 36   0.140167   0.142469  0.136214    0.137881        0.137881   1468393831
# 37   0.137882   0.139202  0.128489    0.130391        0.130391    963364309
# 38   0.130386   0.134627  0.127244    0.128088        0.128088    734879689
# 39   0.128076   0.128641  0.120437    0.123109        0.123109    982046144
#
#     (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  (LINK)Low  (LINK)Close  \
# 35   0.134430   0.143087  0.126405    0.140169  ...        NaN          NaN
# 36   0.140167   0.142469  0.136214    0.137881  ...        NaN          NaN
# 37   0.137882   0.139202  0.128489    0.130391  ...        NaN          NaN
# 38   0.130386   0.134627  0.127244    0.128088  ...        NaN          NaN
# 39   0.128076   0.128641  0.120437    0.123109  ...        NaN          NaN
#
# ...

# %%
df_Criptos.plot(kind="scatter", x="(BNB)Open", y="(BNB)Volume")
# Out:
# <Axes: xlabel='(BNB)Open', ylabel='(BNB)Volume'>

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
df_Criptos.plot(kind="scatter", x="(DOT)High", y ="(DOT)Volume", ax=axs[0][0])
df_Criptos.plot(kind="scatter", x="(BNB)High", y="(BNB)Volume", ax=axs[0][1])
df_Criptos.plot(kind="scatter", x="(ADA)High", y ="(ADA)Volume", ax=axs[1][0])
df_Criptos.plot(kind="scatter", x="(DOT)High", y="(DOT)Volume", ax=axs[1][1])
# Out:
# <Axes: xlabel='(DOT)High', ylabel='(DOT)Volume'>

# %%
k = int(np.ceil(1+np.log2(3333)))
plt.hist(df_Criptos["(BTC)Volume"], bins = k) #bins = [0,30,60,...,200]
plt.xlabel("Volumen")
plt.ylabel("Frecuencia")
plt.title("Histograma de BitCoin")
# Out:
# Text(0.5, 1.0, 'Histograma de BitCoin')

# %%
plt.boxplot(df_Criptos["(BTC)Open"])
plt.ylabel("")
plt.title("")
# Out:
# Text(0.5, 1.0, '')

# %%
df_Criptos["(BTC)Open"].describe()
# Out:
# count    40.000000
# mean      0.121335
# std       0.009580
# min       0.104235
# 25%       0.114997
# 50%       0.122733
# 75%       0.125644
# max       0.140167
# Name: (BTC)Open, dtype: float64

# %%
df_Criptos31 = df_Criptos.iloc[[1, 31]]

# %%
df_Criptos31.shape
# Out:
# (2, 90)

# %%
df_Criptos31.head()
# Out:
#     (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 1    0.136940   0.138023  0.126495    0.128889        0.128889    960646592
# 31   0.124933   0.127506  0.120643    0.121884        0.121884    731025036
#
#     (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  (LINK)Low  (LINK)Close  \
# 1    0.136940   0.138023  0.126495    0.128889  ...  14.062859    14.534426
# 31   0.124933   0.127506  0.120643    0.121884  ...        NaN          NaN
#
#     (LINK)Adj Close  (LINK)Volume  (AVAX)Open  (AVAX)High  (AVAX)Low  \
# 1         14.534426   347472612.0    0.136940    0.138023   0.126495
# 31              NaN           NaN    0.124933    0.127506   0.120643
#
#     (AVAX)Close  (AVAX)Adj Close  (AVAX)Volume
# 1      0.128889         0.128889     960646592
# 31     0.121884         0.121884     731025036
#
# [2 rows x 90 columns]

# %%
df_CriptosA = df_Criptos.iloc[1:31]

# %%
df_CriptosA.shape
# Out:
# (30, 90)

# %%
df_CriptosA.head(31)
# Out:
#     (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  (BTC)Volume  \
# 1    0.136940   0.138023  0.126495    0.128889        0.128889    960646592
# 2    0.128866   0.129103  0.115392    0.122296        0.122296   1413960450
# 3    0.122279   0.126508  0.121579    0.122341        0.122341    642487745
# 4    0.122341   0.128266  0.121454    0.124419        0.124419    734399819
# 5    0.124430   0.125500  0.121617    0.124029        0.124029    598393023
# 6    0.124038   0.125365  0.122959    0.123789        0.123789    328642106
# 7    0.123783   0.126120  0.121827    0.122257        0.122257    429188641
# 8    0.122249   0.123675  0.114731    0.119043        0.119043    951099440
# 9    0.119033   0.128236  0.118895    0.126153        0.126153    783244352
# 10   0.126150   0.128522  0.121920    0.122679        0.122679    526276880
# 11   0.122672   0.128115  0.120630    0.126911        0.126911    616932730
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/Colab Notebooks/CRIPTOS_A.csv'
df_CriptosA.to_csv(file_path, index=False)
